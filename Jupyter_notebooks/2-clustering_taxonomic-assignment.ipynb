# %% [markdown]
# I will attempt to assign taxonomic identity to the set of denovo OTUs obtained from the 532 freshwater pond eDNA samples and PCR controls previously processed using metaBEAT.
#
# I will be using a custom phylogenetically curated reference database. Taxonomic assignment will be performed using a BLAST-based LCA approach.
#
# I will again be using [metaBEAT](https://github.com/HullUni-bioinformatics/metaBEAT) to facilitate reproducibility.
#
# The final result of this notebook will be a taxonomically annotated OTU table in BIOM and tsv format, which I can then use in downstream analysis. BIOM format, and the associated set of python functions, has been developed as a standardized format for representing 'biological sample by observation contingency tables' in the -omics area.
#
# Most of the input data was produced during processing of the eDNA samples. The rest can be found in the folder `../Reference_database`.
#
# I must specify location of and file format that reference sequences come in. Different formats (fasta, GenBank) can be mixed and matched. A simple text file that contains the path to the file and the format specification must be prepared.
#
# The reference sequences in GenBank/fasta format are contained in the directory `../Reference_database`. The files are called `12S_UK...._SATIVA_cleaned.gb` and additional fasta files containing Sanger sequences to supplement records on GenBank.

# %%
# !pwd
# Out:
# /home/working/Harper_et_al_2018/Jupyter_notebooks

# %%
cd ..
# Out:
# /home/working/Harper_et_al_2018

# %%
# !mkdir 3-taxonomic_assignment

# %%
cd 3-taxonomic_assignment/
# Out:
# /home/working/Harper_et_al_2018/3-taxonomic_assignment

# %% [markdown]
# Produce the text file containing the reference sequences using the command line - we call it `REFmap.txt`.

# %%
# !echo '../Reference_database/Amphibians/12S_UKamphibians_SATIVA_cleaned.gb\tgb\n' \
'../Reference_database/Amphibians/Amphibian12S_ReferenceSequences.fasta\tfasta\n' \
'../Reference_database/Reptiles/12S_UKreptiles_SATIVA_cleaned.gb\tgb\n' \
'../Reference_database/Mammals/12S_UKmammals_SATIVA_cleaned.gb\tgb\n' \
'../Reference_database/Birds/12S_UKbirds_SATIVA_cleaned.gb\tgb\n' \
'../Reference_database/Fish/20161026_INBO_12S_fishrefs_hfj_edit.fasta\tfasta\n' \
'../Reference_database/Fish/custom_extended_12S_edit_10_2016.gb\tgb\n' \
'../Reference_database/Fish/RhamphochromisEsox_mt.gb\tgb' > REFmap.txt

# %%
# !cat REFmap.txt
# Out:
# ../Reference_database/Amphibians/12S_UKamphibians_SATIVA_cleaned.gb	gb
#  ../Reference_database/Amphibians/Amphibian12S_ReferenceSequences.fasta	fasta
#  ../Reference_database/Reptiles/12S_UKreptiles_SATIVA_cleaned.gb	gb
#  ../Reference_database/Mammals/12S_UKmammals_SATIVA_cleaned.gb	gb
#  ../Reference_database/Birds/12S_UKbirds_SATIVA_cleaned.gb	gb
#  ../Reference_database/Fish/20161026_INBO_12S_fishrefs_hfj_edit.fasta	fasta
#  ../Reference_database/Fish/custom_extended_12S_edit_10_2016.gb	gb
#  ../Reference_database/Fish/RhamphochromisEsox_mt.gb	gb

# %% [markdown]
# Produce the text file containing non-chimera query sequences - `Querymap.txt`

# %%
# %%bash
#
# #Querymap
# for a in $(ls -l ../2-chimera_detection/ | grep "^d" | perl -ne 'chomp; @a=split(" "); print "$a[-1]\n"')
# do
#     echo -e "$a-nc\tfasta\t../2-chimera_detection/$a/$a-nonchimeras.fasta"
# done > Querymap.txt

# %%
# !cat Querymap.txt
# Out:
# F1-nc	fasta	../2-chimera_detection/F1/F1-nonchimeras.fasta
# F10-nc	fasta	../2-chimera_detection/F10/F10-nonchimeras.fasta
# F100-nc	fasta	../2-chimera_detection/F100/F100-nonchimeras.fasta
# F101-nc	fasta	../2-chimera_detection/F101/F101-nonchimeras.fasta
# F102-nc	fasta	../2-chimera_detection/F102/F102-nonchimeras.fasta
# F103-nc	fasta	../2-chimera_detection/F103/F103-nonchimeras.fasta
# F104-nc	fasta	../2-chimera_detection/F104/F104-nonchimeras.fasta
# F105-nc	fasta	../2-chimera_detection/F105/F105-nonchimeras.fasta
# F106-nc	fasta	../2-chimera_detection/F106/F106-nonchimeras.fasta
# F107-nc	fasta	../2-chimera_detection/F107/F107-nonchimeras.fasta
# F108-nc	fasta	../2-chimera_detection/F108/F108-nonchimeras.fasta
# F109-nc	fasta	../2-chimera_detection/F109/F109-nonchimeras.fasta
# F11-nc	fasta	../2-chimera_detection/F11/F11-nonchimeras.fasta
# F110-nc	fasta	../2-chimera_detection/F110/F110-nonchimeras.fasta
# F111-nc	fasta	../2-chimera_detection/F111/F111-nonchimeras.fasta
# F112-nc	fasta	../2-chimera_detection/F112/F112-nonchimeras.fasta
# F113-nc	fasta	../2-chimera_detection/F113/F113-nonchimeras.fasta
# F114-nc	fasta	../2-chimera_detection/F114/F114-nonchimeras.fasta
# F115-nc	fasta	../2-chimera_detection/F115/F115-nonchimeras.fasta
# F116-nc	fasta	../2-chimera_detection/F116/F116-nonchimeras.fasta
# F117-nc	fasta	../2-chimera_detection/F117/F117-nonchimeras.fasta
# F118-nc	fasta	../2-chimera_detection/F118/F118-nonchimeras.fasta
# F119-nc	fasta	../2-chimera_detection/F119/F119-nonchimeras.fasta
# F12-nc	fasta	../2-chimera_detection/F12/F12-nonchimeras.fasta
# F120-nc	fasta	../2-chimera_detection/F120/F120-nonchimeras.fasta
# F121-nc	fasta	../2-chimera_detection/F121/F121-nonchimeras.fasta
# F122-nc	fasta	../2-chimera_detection/F122/F122-nonchimeras.fasta
# F123-nc	fasta	../2-chimera_detection/F123/F123-nonchimeras.fasta
# F124-nc	fasta	../2-chimera_detection/F124/F124-nonchimeras.fasta
# F125-nc	fasta	../2-chimera_detection/F125/F125-nonchimeras.fasta
# F126-nc	fasta	../2-chimera_detection/F126/F126-nonchimeras.fasta
# F127-nc	fasta	../2-chimera_detection/F127/F127-nonchimeras.fasta
# F128-nc	fasta	../2-chimera_detection/F128/F128-nonchimeras.fasta
# F129-nc	fasta	../2-chimera_detection/F129/F129-nonchimeras.fasta
# F13-nc	fasta	../2-chimera_detection/F13/F13-nonchimeras.fasta
# F130-nc	fasta	../2-chimera_detection/F130/F130-nonchimeras.fasta
# F131-nc	fasta	../2-chimera_detection/F131/F131-nonchimeras.fasta
# F132-nc	fasta	../2-chimera_detection/F132/F132-nonchimeras.fasta
# F133-nc	fasta	../2-chimera_detection/F133/F133-nonchimeras.fasta
# F134-nc	fasta	../2-chimera_detection/F134/F134-nonchimeras.fasta
# F135-nc	fasta	../2-chimera_detection/F135/F135-nonchimeras.fasta
# F136-nc	fasta	../2-chimera_detection/F136/F136-nonchimeras.fasta
# F137-nc	fasta	../2-chimera_detection/F137/F137-nonchimeras.fasta
# F138-nc	fasta	../2-chimera_detection/F138/F138-nonchimeras.fasta
# F139-nc	fasta	../2-chimera_detection/F139/F139-nonchimeras.fasta
# F14-nc	fasta	../2-chimera_detection/F14/F14-nonchimeras.fasta
# F140-nc	fasta	../2-chimera_detection/F140/F140-nonchimeras.fasta
# F141-nc	fasta	../2-chimera_detection/F141/F141-nonchimeras.fasta
# F142-nc	fasta	../2-chimera_detection/F142/F142-nonchimeras.fasta
# F143-nc	fasta	../2-chimera_detection/F143/F143-nonchimeras.fasta
# F144-nc	fasta	../2-chimera_detection/F144/F144-nonchimeras.fasta
# F145-nc	fasta	../2-chimera_detection/F145/F145-nonchimeras.fasta
# F146-nc	fasta	../2-chimera_detection/F146/F146-nonchimeras.fasta
# F147-nc	fasta	../2-chimera_detection/F147/F147-nonchimeras.fasta
# F148-nc	fasta	../2-chimera_detection/F148/F148-nonchimeras.fasta
# F149-nc	fasta	../2-chimera_detection/F149/F149-nonchimeras.fasta
# F15-nc	fasta	../2-chimera_detection/F15/F15-nonchimeras.fasta
# F150-nc	fasta	../2-chimera_detection/F150/F150-nonchimeras.fasta
# F151-nc	fasta	../2-chimera_detection/F151/F151-nonchimeras.fasta
# F152-nc	fasta	../2-chimera_detection/F152/F152-nonchimeras.fasta
# F153-nc	fasta	../2-chimera_detection/F153/F153-nonchimeras.fasta
# F154-nc	fasta	../2-chimera_detection/F154/F154-nonchimeras.fasta
# F155-nc	fasta	../2-chimera_detection/F155/F155-nonchimeras.fasta
# F156-nc	fasta	../2-chimera_detection/F156/F156-nonchimeras.fasta
# F157-nc	fasta	../2-chimera_detection/F157/F157-nonchimeras.fasta
# F158-nc	fasta	../2-chimera_detection/F158/F158-nonchimeras.fasta
# F159-nc	fasta	../2-chimera_detection/F159/F159-nonchimeras.fasta
# F16-nc	fasta	../2-chimera_detection/F16/F16-nonchimeras.fasta
# F160-nc	fasta	../2-chimera_detection/F160/F160-nonchimeras.fasta
# F161-nc	fasta	../2-chimera_detection/F161/F161-nonchimeras.fasta
# F162-nc	fasta	../2-chimera_detection/F162/F162-nonchimeras.fasta
# F163-nc	fasta	../2-chimera_detection/F163/F163-nonchimeras.fasta
# F164-nc	fasta	../2-chimera_detection/F164/F164-nonchimeras.fasta
# F165-nc	fasta	../2-chimera_detection/F165/F165-nonchimeras.fasta
# F166-nc	fasta	../2-chimera_detection/F166/F166-nonchimeras.fasta
# F167-nc	fasta	../2-chimera_detection/F167/F167-nonchimeras.fasta
# F168-nc	fasta	../2-chimera_detection/F168/F168-nonchimeras.fasta
# F169-nc	fasta	../2-chimera_detection/F169/F169-nonchimeras.fasta
# F17-nc	fasta	../2-chimera_detection/F17/F17-nonchimeras.fasta
# F170-nc	fasta	../2-chimera_detection/F170/F170-nonchimeras.fasta
# F171-nc	fasta	../2-chimera_detection/F171/F171-nonchimeras.fasta
# F172-nc	fasta	../2-chimera_detection/F172/F172-nonchimeras.fasta
# F173-nc	fasta	../2-chimera_detection/F173/F173-nonchimeras.fasta
# F174-nc	fasta	../2-chimera_detection/F174/F174-nonchimeras.fasta
# F175-nc	fasta	../2-chimera_detection/F175/F175-nonchimeras.fasta
# F176-nc	fasta	../2-chimera_detection/F176/F176-nonchimeras.fasta
# F177-nc	fasta	../2-chimera_detection/F177/F177-nonchimeras.fasta
# F178-nc	fasta	../2-chimera_detection/F178/F178-nonchimeras.fasta
# F179-nc	fasta	../2-chimera_detection/F179/F179-nonchimeras.fasta
# F18-nc	fasta	../2-chimera_detection/F18/F18-nonchimeras.fasta
# F180-nc	fasta	../2-chimera_detection/F180/F180-nonchimeras.fasta
# F181-nc	fasta	../2-chimera_detection/F181/F181-nonchimeras.fasta
# F182-nc	fasta	../2-chimera_detection/F182/F182-nonchimeras.fasta
# F183-nc	fasta	../2-chimera_detection/F183/F183-nonchimeras.fasta
# F184-nc	fasta	../2-chimera_detection/F184/F184-nonchimeras.fasta
# F185-nc	fasta	../2-chimera_detection/F185/F185-nonchimeras.fasta
# F186-nc	fasta	../2-chimera_detection/F186/F186-nonchimeras.fasta
# F187-nc	fasta	../2-chimera_detection/F187/F187-nonchimeras.fasta
# F188-nc	fasta	../2-chimera_detection/F188/F188-nonchimeras.fasta
# F189-nc	fasta	../2-chimera_detection/F189/F189-nonchimeras.fasta
# F19-nc	fasta	../2-chimera_detection/F19/F19-nonchimeras.fasta
# F190-nc	fasta	../2-chimera_detection/F190/F190-nonchimeras.fasta
# F191-nc	fasta	../2-chimera_detection/F191/F191-nonchimeras.fasta
# F192-nc	fasta	../2-chimera_detection/F192/F192-nonchimeras.fasta
# F193-nc	fasta	../2-chimera_detection/F193/F193-nonchimeras.fasta
# F194-nc	fasta	../2-chimera_detection/F194/F194-nonchimeras.fasta
# F195-nc	fasta	../2-chimera_detection/F195/F195-nonchimeras.fasta
# F196-nc	fasta	../2-chimera_detection/F196/F196-nonchimeras.fasta
# F197-nc	fasta	../2-chimera_detection/F197/F197-nonchimeras.fasta
# F198-nc	fasta	../2-chimera_detection/F198/F198-nonchimeras.fasta
# F199-nc	fasta	../2-chimera_detection/F199/F199-nonchimeras.fasta
# F2-nc	fasta	../2-chimera_detection/F2/F2-nonchimeras.fasta
# F20-nc	fasta	../2-chimera_detection/F20/F20-nonchimeras.fasta
# F200-nc	fasta	../2-chimera_detection/F200/F200-nonchimeras.fasta
# F201-nc	fasta	../2-chimera_detection/F201/F201-nonchimeras.fasta
# F202-nc	fasta	../2-chimera_detection/F202/F202-nonchimeras.fasta
# F203-nc	fasta	../2-chimera_detection/F203/F203-nonchimeras.fasta
# F204-nc	fasta	../2-chimera_detection/F204/F204-nonchimeras.fasta
# F205-nc	fasta	../2-chimera_detection/F205/F205-nonchimeras.fasta
# F206-nc	fasta	../2-chimera_detection/F206/F206-nonchimeras.fasta
# F207-nc	fasta	../2-chimera_detection/F207/F207-nonchimeras.fasta
# F208-nc	fasta	../2-chimera_detection/F208/F208-nonchimeras.fasta
# F209-nc	fasta	../2-chimera_detection/F209/F209-nonchimeras.fasta
# F21-nc	fasta	../2-chimera_detection/F21/F21-nonchimeras.fasta
# F210-nc	fasta	../2-chimera_detection/F210/F210-nonchimeras.fasta
# F211-nc	fasta	../2-chimera_detection/F211/F211-nonchimeras.fasta
# F212-nc	fasta	../2-chimera_detection/F212/F212-nonchimeras.fasta
# F213-nc	fasta	../2-chimera_detection/F213/F213-nonchimeras.fasta
# F214-nc	fasta	../2-chimera_detection/F214/F214-nonchimeras.fasta
# F215-nc	fasta	../2-chimera_detection/F215/F215-nonchimeras.fasta
# F216-nc	fasta	../2-chimera_detection/F216/F216-nonchimeras.fasta
# F217-nc	fasta	../2-chimera_detection/F217/F217-nonchimeras.fasta
# F218-nc	fasta	../2-chimera_detection/F218/F218-nonchimeras.fasta
# F219-nc	fasta	../2-chimera_detection/F219/F219-nonchimeras.fasta
# F22-nc	fasta	../2-chimera_detection/F22/F22-nonchimeras.fasta
# F220-nc	fasta	../2-chimera_detection/F220/F220-nonchimeras.fasta
# F221-nc	fasta	../2-chimera_detection/F221/F221-nonchimeras.fasta
# F222-nc	fasta	../2-chimera_detection/F222/F222-nonchimeras.fasta
# F223-nc	fasta	../2-chimera_detection/F223/F223-nonchimeras.fasta
# F224-nc	fasta	../2-chimera_detection/F224/F224-nonchimeras.fasta
# F225-nc	fasta	../2-chimera_detection/F225/F225-nonchimeras.fasta
# F226-nc	fasta	../2-chimera_detection/F226/F226-nonchimeras.fasta
# F227-nc	fasta	../2-chimera_detection/F227/F227-nonchimeras.fasta
# F228-nc	fasta	../2-chimera_detection/F228/F228-nonchimeras.fasta
# F229-nc	fasta	../2-chimera_detection/F229/F229-nonchimeras.fasta
# F23-nc	fasta	../2-chimera_detection/F23/F23-nonchimeras.fasta
# F230-nc	fasta	../2-chimera_detection/F230/F230-nonchimeras.fasta
# F231-nc	fasta	../2-chimera_detection/F231/F231-nonchimeras.fasta
# F232-nc	fasta	../2-chimera_detection/F232/F232-nonchimeras.fasta
# F233-nc	fasta	../2-chimera_detection/F233/F233-nonchimeras.fasta
# F234-nc	fasta	../2-chimera_detection/F234/F234-nonchimeras.fasta
# F235-nc	fasta	../2-chimera_detection/F235/F235-nonchimeras.fasta
# F236-nc	fasta	../2-chimera_detection/F236/F236-nonchimeras.fasta
# F237-nc	fasta	../2-chimera_detection/F237/F237-nonchimeras.fasta
# F238-nc	fasta	../2-chimera_detection/F238/F238-nonchimeras.fasta
# F239-nc	fasta	../2-chimera_detection/F239/F239-nonchimeras.fasta
# F24-nc	fasta	../2-chimera_detection/F24/F24-nonchimeras.fasta
# F240-nc	fasta	../2-chimera_detection/F240/F240-nonchimeras.fasta
# F241-nc	fasta	../2-chimera_detection/F241/F241-nonchimeras.fasta
# F242-nc	fasta	../2-chimera_detection/F242/F242-nonchimeras.fasta
# F243-nc	fasta	../2-chimera_detection/F243/F243-nonchimeras.fasta
# F244-nc	fasta	../2-chimera_detection/F244/F244-nonchimeras.fasta
# F245-nc	fasta	../2-chimera_detection/F245/F245-nonchimeras.fasta
# F246-nc	fasta	../2-chimera_detection/F246/F246-nonchimeras.fasta
# F247-nc	fasta	../2-chimera_detection/F247/F247-nonchimeras.fasta
# F248-nc	fasta	../2-chimera_detection/F248/F248-nonchimeras.fasta
# F249-nc	fasta	../2-chimera_detection/F249/F249-nonchimeras.fasta
# F25-nc	fasta	../2-chimera_detection/F25/F25-nonchimeras.fasta
# F250-nc	fasta	../2-chimera_detection/F250/F250-nonchimeras.fasta
# F251-nc	fasta	../2-chimera_detection/F251/F251-nonchimeras.fasta
# F252-nc	fasta	../2-chimera_detection/F252/F252-nonchimeras.fasta
# F253-nc	fasta	../2-chimera_detection/F253/F253-nonchimeras.fasta
# F254-nc	fasta	../2-chimera_detection/F254/F254-nonchimeras.fasta
# F255-nc	fasta	../2-chimera_detection/F255/F255-nonchimeras.fasta
# F256-nc	fasta	../2-chimera_detection/F256/F256-nonchimeras.fasta
# F257-nc	fasta	../2-chimera_detection/F257/F257-nonchimeras.fasta
# F258-nc	fasta	../2-chimera_detection/F258/F258-nonchimeras.fasta
# F259-nc	fasta	../2-chimera_detection/F259/F259-nonchimeras.fasta
# F26-nc	fasta	../2-chimera_detection/F26/F26-nonchimeras.fasta
# F260-nc	fasta	../2-chimera_detection/F260/F260-nonchimeras.fasta
# F261-nc	fasta	../2-chimera_detection/F261/F261-nonchimeras.fasta
# F262-nc	fasta	../2-chimera_detection/F262/F262-nonchimeras.fasta
# F263-nc	fasta	../2-chimera_detection/F263/F263-nonchimeras.fasta
# F264-nc	fasta	../2-chimera_detection/F264/F264-nonchimeras.fasta
# F265-nc	fasta	../2-chimera_detection/F265/F265-nonchimeras.fasta
# F266-nc	fasta	../2-chimera_detection/F266/F266-nonchimeras.fasta
# F267-nc	fasta	../2-chimera_detection/F267/F267-nonchimeras.fasta
# F268-nc	fasta	../2-chimera_detection/F268/F268-nonchimeras.fasta
# F269-nc	fasta	../2-chimera_detection/F269/F269-nonchimeras.fasta
# F27-nc	fasta	../2-chimera_detection/F27/F27-nonchimeras.fasta
# F270-nc	fasta	../2-chimera_detection/F270/F270-nonchimeras.fasta
# F271-nc	fasta	../2-chimera_detection/F271/F271-nonchimeras.fasta
# F272-nc	fasta	../2-chimera_detection/F272/F272-nonchimeras.fasta
# F273-nc	fasta	../2-chimera_detection/F273/F273-nonchimeras.fasta
# F274-nc	fasta	../2-chimera_detection/F274/F274-nonchimeras.fasta
# F275-nc	fasta	../2-chimera_detection/F275/F275-nonchimeras.fasta
# F276-nc	fasta	../2-chimera_detection/F276/F276-nonchimeras.fasta
# F277-nc	fasta	../2-chimera_detection/F277/F277-nonchimeras.fasta
# F278-nc	fasta	../2-chimera_detection/F278/F278-nonchimeras.fasta
# F279-nc	fasta	../2-chimera_detection/F279/F279-nonchimeras.fasta
# F28-nc	fasta	../2-chimera_detection/F28/F28-nonchimeras.fasta
# F280-nc	fasta	../2-chimera_detection/F280/F280-nonchimeras.fasta
# F281-nc	fasta	../2-chimera_detection/F281/F281-nonchimeras.fasta
# F282-nc	fasta	../2-chimera_detection/F282/F282-nonchimeras.fasta
# F283-nc	fasta	../2-chimera_detection/F283/F283-nonchimeras.fasta
# F284-nc	fasta	../2-chimera_detection/F284/F284-nonchimeras.fasta
# F285-nc	fasta	../2-chimera_detection/F285/F285-nonchimeras.fasta
# F286-nc	fasta	../2-chimera_detection/F286/F286-nonchimeras.fasta
# F287-nc	fasta	../2-chimera_detection/F287/F287-nonchimeras.fasta
# F288-nc	fasta	../2-chimera_detection/F288/F288-nonchimeras.fasta
# F289-nc	fasta	../2-chimera_detection/F289/F289-nonchimeras.fasta
# F29-nc	fasta	../2-chimera_detection/F29/F29-nonchimeras.fasta
# F290-nc	fasta	../2-chimera_detection/F290/F290-nonchimeras.fasta
# F291-nc	fasta	../2-chimera_detection/F291/F291-nonchimeras.fasta
# F292-nc	fasta	../2-chimera_detection/F292/F292-nonchimeras.fasta
# F293-nc	fasta	../2-chimera_detection/F293/F293-nonchimeras.fasta
# F294-nc	fasta	../2-chimera_detection/F294/F294-nonchimeras.fasta
# F295-nc	fasta	../2-chimera_detection/F295/F295-nonchimeras.fasta
# F296-nc	fasta	../2-chimera_detection/F296/F296-nonchimeras.fasta
# F297-nc	fasta	../2-chimera_detection/F297/F297-nonchimeras.fasta
# F298-nc	fasta	../2-chimera_detection/F298/F298-nonchimeras.fasta
# F299-nc	fasta	../2-chimera_detection/F299/F299-nonchimeras.fasta
# F3-nc	fasta	../2-chimera_detection/F3/F3-nonchimeras.fasta
# F30-nc	fasta	../2-chimera_detection/F30/F30-nonchimeras.fasta
# F300-nc	fasta	../2-chimera_detection/F300/F300-nonchimeras.fasta
# F301-nc	fasta	../2-chimera_detection/F301/F301-nonchimeras.fasta
# F302-nc	fasta	../2-chimera_detection/F302/F302-nonchimeras.fasta
# F303-nc	fasta	../2-chimera_detection/F303/F303-nonchimeras.fasta
# F304-nc	fasta	../2-chimera_detection/F304/F304-nonchimeras.fasta
# F305-nc	fasta	../2-chimera_detection/F305/F305-nonchimeras.fasta
# F306-nc	fasta	../2-chimera_detection/F306/F306-nonchimeras.fasta
# F307-nc	fasta	../2-chimera_detection/F307/F307-nonchimeras.fasta
# F308-nc	fasta	../2-chimera_detection/F308/F308-nonchimeras.fasta
# F309-nc	fasta	../2-chimera_detection/F309/F309-nonchimeras.fasta
# F31-nc	fasta	../2-chimera_detection/F31/F31-nonchimeras.fasta
# F310-nc	fasta	../2-chimera_detection/F310/F310-nonchimeras.fasta
# F311-nc	fasta	../2-chimera_detection/F311/F311-nonchimeras.fasta
# F312-nc	fasta	../2-chimera_detection/F312/F312-nonchimeras.fasta
# F313-nc	fasta	../2-chimera_detection/F313/F313-nonchimeras.fasta
# F314-nc	fasta	../2-chimera_detection/F314/F314-nonchimeras.fasta
# F315-nc	fasta	../2-chimera_detection/F315/F315-nonchimeras.fasta
# F316-nc	fasta	../2-chimera_detection/F316/F316-nonchimeras.fasta
# F317-nc	fasta	../2-chimera_detection/F317/F317-nonchimeras.fasta
# F318-nc	fasta	../2-chimera_detection/F318/F318-nonchimeras.fasta
# F319-nc	fasta	../2-chimera_detection/F319/F319-nonchimeras.fasta
# F32-nc	fasta	../2-chimera_detection/F32/F32-nonchimeras.fasta
# F320-nc	fasta	../2-chimera_detection/F320/F320-nonchimeras.fasta
# F321-nc	fasta	../2-chimera_detection/F321/F321-nonchimeras.fasta
# F322-nc	fasta	../2-chimera_detection/F322/F322-nonchimeras.fasta
# F323-nc	fasta	../2-chimera_detection/F323/F323-nonchimeras.fasta
# F324-nc	fasta	../2-chimera_detection/F324/F324-nonchimeras.fasta
# F325-nc	fasta	../2-chimera_detection/F325/F325-nonchimeras.fasta
# F326-nc	fasta	../2-chimera_detection/F326/F326-nonchimeras.fasta
# F327-nc	fasta	../2-chimera_detection/F327/F327-nonchimeras.fasta
# F328-nc	fasta	../2-chimera_detection/F328/F328-nonchimeras.fasta
# F329-nc	fasta	../2-chimera_detection/F329/F329-nonchimeras.fasta
# F33-nc	fasta	../2-chimera_detection/F33/F33-nonchimeras.fasta
# F330-nc	fasta	../2-chimera_detection/F330/F330-nonchimeras.fasta
# F331-nc	fasta	../2-chimera_detection/F331/F331-nonchimeras.fasta
# F332-nc	fasta	../2-chimera_detection/F332/F332-nonchimeras.fasta
# F333-nc	fasta	../2-chimera_detection/F333/F333-nonchimeras.fasta
# F334-nc	fasta	../2-chimera_detection/F334/F334-nonchimeras.fasta
# F335-nc	fasta	../2-chimera_detection/F335/F335-nonchimeras.fasta
# F336-nc	fasta	../2-chimera_detection/F336/F336-nonchimeras.fasta
# F337-nc	fasta	../2-chimera_detection/F337/F337-nonchimeras.fasta
# F338-nc	fasta	../2-chimera_detection/F338/F338-nonchimeras.fasta
# F339-nc	fasta	../2-chimera_detection/F339/F339-nonchimeras.fasta
# F34-nc	fasta	../2-chimera_detection/F34/F34-nonchimeras.fasta
# F340-nc	fasta	../2-chimera_detection/F340/F340-nonchimeras.fasta
# F341-nc	fasta	../2-chimera_detection/F341/F341-nonchimeras.fasta
# F342-nc	fasta	../2-chimera_detection/F342/F342-nonchimeras.fasta
# F343-nc	fasta	../2-chimera_detection/F343/F343-nonchimeras.fasta
# F344-nc	fasta	../2-chimera_detection/F344/F344-nonchimeras.fasta
# F345-nc	fasta	../2-chimera_detection/F345/F345-nonchimeras.fasta
# F346-nc	fasta	../2-chimera_detection/F346/F346-nonchimeras.fasta
# F347-nc	fasta	../2-chimera_detection/F347/F347-nonchimeras.fasta
# F348-nc	fasta	../2-chimera_detection/F348/F348-nonchimeras.fasta
# F349-nc	fasta	../2-chimera_detection/F349/F349-nonchimeras.fasta
# F35-nc	fasta	../2-chimera_detection/F35/F35-nonchimeras.fasta
# F350-nc	fasta	../2-chimera_detection/F350/F350-nonchimeras.fasta
# F351-nc	fasta	../2-chimera_detection/F351/F351-nonchimeras.fasta
# F352-nc	fasta	../2-chimera_detection/F352/F352-nonchimeras.fasta
# F353-nc	fasta	../2-chimera_detection/F353/F353-nonchimeras.fasta
# F354-nc	fasta	../2-chimera_detection/F354/F354-nonchimeras.fasta
# F355-nc	fasta	../2-chimera_detection/F355/F355-nonchimeras.fasta
# F356-nc	fasta	../2-chimera_detection/F356/F356-nonchimeras.fasta
# F357-nc	fasta	../2-chimera_detection/F357/F357-nonchimeras.fasta
# F358-nc	fasta	../2-chimera_detection/F358/F358-nonchimeras.fasta
# F359-nc	fasta	../2-chimera_detection/F359/F359-nonchimeras.fasta
# F36-nc	fasta	../2-chimera_detection/F36/F36-nonchimeras.fasta
# F360-nc	fasta	../2-chimera_detection/F360/F360-nonchimeras.fasta
# F361-nc	fasta	../2-chimera_detection/F361/F361-nonchimeras.fasta
# F362-nc	fasta	../2-chimera_detection/F362/F362-nonchimeras.fasta
# F363-nc	fasta	../2-chimera_detection/F363/F363-nonchimeras.fasta
# F364-nc	fasta	../2-chimera_detection/F364/F364-nonchimeras.fasta
# F365-nc	fasta	../2-chimera_detection/F365/F365-nonchimeras.fasta
# F366-nc	fasta	../2-chimera_detection/F366/F366-nonchimeras.fasta
# F367-nc	fasta	../2-chimera_detection/F367/F367-nonchimeras.fasta
# F368-nc	fasta	../2-chimera_detection/F368/F368-nonchimeras.fasta
# F369-nc	fasta	../2-chimera_detection/F369/F369-nonchimeras.fasta
# F37-nc	fasta	../2-chimera_detection/F37/F37-nonchimeras.fasta
# F370-nc	fasta	../2-chimera_detection/F370/F370-nonchimeras.fasta
# F371-nc	fasta	../2-chimera_detection/F371/F371-nonchimeras.fasta
# F372-nc	fasta	../2-chimera_detection/F372/F372-nonchimeras.fasta
# F373-nc	fasta	../2-chimera_detection/F373/F373-nonchimeras.fasta
# F374-nc	fasta	../2-chimera_detection/F374/F374-nonchimeras.fasta
# F375-nc	fasta	../2-chimera_detection/F375/F375-nonchimeras.fasta
# F376-nc	fasta	../2-chimera_detection/F376/F376-nonchimeras.fasta
# F377-nc	fasta	../2-chimera_detection/F377/F377-nonchimeras.fasta
# F378-nc	fasta	../2-chimera_detection/F378/F378-nonchimeras.fasta
# F379-nc	fasta	../2-chimera_detection/F379/F379-nonchimeras.fasta
# F38-nc	fasta	../2-chimera_detection/F38/F38-nonchimeras.fasta
# F380-nc	fasta	../2-chimera_detection/F380/F380-nonchimeras.fasta
# F381-nc	fasta	../2-chimera_detection/F381/F381-nonchimeras.fasta
# F382-nc	fasta	../2-chimera_detection/F382/F382-nonchimeras.fasta
# F383-nc	fasta	../2-chimera_detection/F383/F383-nonchimeras.fasta
# F384-nc	fasta	../2-chimera_detection/F384/F384-nonchimeras.fasta
# F385-nc	fasta	../2-chimera_detection/F385/F385-nonchimeras.fasta
# F386-nc	fasta	../2-chimera_detection/F386/F386-nonchimeras.fasta
# F387-nc	fasta	../2-chimera_detection/F387/F387-nonchimeras.fasta
# F388-nc	fasta	../2-chimera_detection/F388/F388-nonchimeras.fasta
# F389-nc	fasta	../2-chimera_detection/F389/F389-nonchimeras.fasta
# F39-nc	fasta	../2-chimera_detection/F39/F39-nonchimeras.fasta
# F390-nc	fasta	../2-chimera_detection/F390/F390-nonchimeras.fasta
# F391-nc	fasta	../2-chimera_detection/F391/F391-nonchimeras.fasta
# F392-nc	fasta	../2-chimera_detection/F392/F392-nonchimeras.fasta
# F393-nc	fasta	../2-chimera_detection/F393/F393-nonchimeras.fasta
# F394-nc	fasta	../2-chimera_detection/F394/F394-nonchimeras.fasta
# F395-nc	fasta	../2-chimera_detection/F395/F395-nonchimeras.fasta
# F396-nc	fasta	../2-chimera_detection/F396/F396-nonchimeras.fasta
# F397-nc	fasta	../2-chimera_detection/F397/F397-nonchimeras.fasta
# F398-nc	fasta	../2-chimera_detection/F398/F398-nonchimeras.fasta
# F399-nc	fasta	../2-chimera_detection/F399/F399-nonchimeras.fasta
# F4-nc	fasta	../2-chimera_detection/F4/F4-nonchimeras.fasta
# F40-nc	fasta	../2-chimera_detection/F40/F40-nonchimeras.fasta
# F400-nc	fasta	../2-chimera_detection/F400/F400-nonchimeras.fasta
# F401-nc	fasta	../2-chimera_detection/F401/F401-nonchimeras.fasta
# F402-nc	fasta	../2-chimera_detection/F402/F402-nonchimeras.fasta
# F403-nc	fasta	../2-chimera_detection/F403/F403-nonchimeras.fasta
# F404-nc	fasta	../2-chimera_detection/F404/F404-nonchimeras.fasta
# F405-nc	fasta	../2-chimera_detection/F405/F405-nonchimeras.fasta
# F406-nc	fasta	../2-chimera_detection/F406/F406-nonchimeras.fasta
# F407-nc	fasta	../2-chimera_detection/F407/F407-nonchimeras.fasta
# F408-nc	fasta	../2-chimera_detection/F408/F408-nonchimeras.fasta
# F409-nc	fasta	../2-chimera_detection/F409/F409-nonchimeras.fasta
# F41-nc	fasta	../2-chimera_detection/F41/F41-nonchimeras.fasta
# F410-nc	fasta	../2-chimera_detection/F410/F410-nonchimeras.fasta
# F411-nc	fasta	../2-chimera_detection/F411/F411-nonchimeras.fasta
# F412-nc	fasta	../2-chimera_detection/F412/F412-nonchimeras.fasta
# F413-nc	fasta	../2-chimera_detection/F413/F413-nonchimeras.fasta
# F414-nc	fasta	../2-chimera_detection/F414/F414-nonchimeras.fasta
# F415-nc	fasta	../2-chimera_detection/F415/F415-nonchimeras.fasta
# F416-nc	fasta	../2-chimera_detection/F416/F416-nonchimeras.fasta
# F417-nc	fasta	../2-chimera_detection/F417/F417-nonchimeras.fasta
# F418-nc	fasta	../2-chimera_detection/F418/F418-nonchimeras.fasta
# F419-nc	fasta	../2-chimera_detection/F419/F419-nonchimeras.fasta
# F42-nc	fasta	../2-chimera_detection/F42/F42-nonchimeras.fasta
# F420-nc	fasta	../2-chimera_detection/F420/F420-nonchimeras.fasta
# F421-nc	fasta	../2-chimera_detection/F421/F421-nonchimeras.fasta
# F422-nc	fasta	../2-chimera_detection/F422/F422-nonchimeras.fasta
# F423-nc	fasta	../2-chimera_detection/F423/F423-nonchimeras.fasta
# F424-nc	fasta	../2-chimera_detection/F424/F424-nonchimeras.fasta
# F425-nc	fasta	../2-chimera_detection/F425/F425-nonchimeras.fasta
# F426-nc	fasta	../2-chimera_detection/F426/F426-nonchimeras.fasta
# F427-nc	fasta	../2-chimera_detection/F427/F427-nonchimeras.fasta
# F428-nc	fasta	../2-chimera_detection/F428/F428-nonchimeras.fasta
# F429-nc	fasta	../2-chimera_detection/F429/F429-nonchimeras.fasta
# F43-nc	fasta	../2-chimera_detection/F43/F43-nonchimeras.fasta
# F430-nc	fasta	../2-chimera_detection/F430/F430-nonchimeras.fasta
# F431-nc	fasta	../2-chimera_detection/F431/F431-nonchimeras.fasta
# F432-nc	fasta	../2-chimera_detection/F432/F432-nonchimeras.fasta
# F433-nc	fasta	../2-chimera_detection/F433/F433-nonchimeras.fasta
# F434-nc	fasta	../2-chimera_detection/F434/F434-nonchimeras.fasta
# F435-nc	fasta	../2-chimera_detection/F435/F435-nonchimeras.fasta
# F436-nc	fasta	../2-chimera_detection/F436/F436-nonchimeras.fasta
# F437-nc	fasta	../2-chimera_detection/F437/F437-nonchimeras.fasta
# F438-nc	fasta	../2-chimera_detection/F438/F438-nonchimeras.fasta
# F439-nc	fasta	../2-chimera_detection/F439/F439-nonchimeras.fasta
# F44-nc	fasta	../2-chimera_detection/F44/F44-nonchimeras.fasta
# F440-nc	fasta	../2-chimera_detection/F440/F440-nonchimeras.fasta
# F441-nc	fasta	../2-chimera_detection/F441/F441-nonchimeras.fasta
# F442-nc	fasta	../2-chimera_detection/F442/F442-nonchimeras.fasta
# F443-nc	fasta	../2-chimera_detection/F443/F443-nonchimeras.fasta
# F444-nc	fasta	../2-chimera_detection/F444/F444-nonchimeras.fasta
# F445-nc	fasta	../2-chimera_detection/F445/F445-nonchimeras.fasta
# F446-nc	fasta	../2-chimera_detection/F446/F446-nonchimeras.fasta
# F447-nc	fasta	../2-chimera_detection/F447/F447-nonchimeras.fasta
# F448-nc	fasta	../2-chimera_detection/F448/F448-nonchimeras.fasta
# F449-nc	fasta	../2-chimera_detection/F449/F449-nonchimeras.fasta
# F45-nc	fasta	../2-chimera_detection/F45/F45-nonchimeras.fasta
# F450-nc	fasta	../2-chimera_detection/F450/F450-nonchimeras.fasta
# F451-nc	fasta	../2-chimera_detection/F451/F451-nonchimeras.fasta
# F452-nc	fasta	../2-chimera_detection/F452/F452-nonchimeras.fasta
# F453-nc	fasta	../2-chimera_detection/F453/F453-nonchimeras.fasta
# F454-nc	fasta	../2-chimera_detection/F454/F454-nonchimeras.fasta
# F455-nc	fasta	../2-chimera_detection/F455/F455-nonchimeras.fasta
# F456-nc	fasta	../2-chimera_detection/F456/F456-nonchimeras.fasta
# F457-nc	fasta	../2-chimera_detection/F457/F457-nonchimeras.fasta
# F458-nc	fasta	../2-chimera_detection/F458/F458-nonchimeras.fasta
# F459-nc	fasta	../2-chimera_detection/F459/F459-nonchimeras.fasta
# F46-nc	fasta	../2-chimera_detection/F46/F46-nonchimeras.fasta
# F460-nc	fasta	../2-chimera_detection/F460/F460-nonchimeras.fasta
# F461-nc	fasta	../2-chimera_detection/F461/F461-nonchimeras.fasta
# F462-nc	fasta	../2-chimera_detection/F462/F462-nonchimeras.fasta
# F463-nc	fasta	../2-chimera_detection/F463/F463-nonchimeras.fasta
# F464-nc	fasta	../2-chimera_detection/F464/F464-nonchimeras.fasta
# F465-nc	fasta	../2-chimera_detection/F465/F465-nonchimeras.fasta
# F466-nc	fasta	../2-chimera_detection/F466/F466-nonchimeras.fasta
# F467-nc	fasta	../2-chimera_detection/F467/F467-nonchimeras.fasta
# F468-nc	fasta	../2-chimera_detection/F468/F468-nonchimeras.fasta
# F469-nc	fasta	../2-chimera_detection/F469/F469-nonchimeras.fasta
# F47-nc	fasta	../2-chimera_detection/F47/F47-nonchimeras.fasta
# F470-nc	fasta	../2-chimera_detection/F470/F470-nonchimeras.fasta
# F471-nc	fasta	../2-chimera_detection/F471/F471-nonchimeras.fasta
# F472-nc	fasta	../2-chimera_detection/F472/F472-nonchimeras.fasta
# F473-nc	fasta	../2-chimera_detection/F473/F473-nonchimeras.fasta
# F474-nc	fasta	../2-chimera_detection/F474/F474-nonchimeras.fasta
# F475-nc	fasta	../2-chimera_detection/F475/F475-nonchimeras.fasta
# F476-nc	fasta	../2-chimera_detection/F476/F476-nonchimeras.fasta
# F477-nc	fasta	../2-chimera_detection/F477/F477-nonchimeras.fasta
# F478-nc	fasta	../2-chimera_detection/F478/F478-nonchimeras.fasta
# F479-nc	fasta	../2-chimera_detection/F479/F479-nonchimeras.fasta
# F48-nc	fasta	../2-chimera_detection/F48/F48-nonchimeras.fasta
# F480-nc	fasta	../2-chimera_detection/F480/F480-nonchimeras.fasta
# F481-nc	fasta	../2-chimera_detection/F481/F481-nonchimeras.fasta
# F482-nc	fasta	../2-chimera_detection/F482/F482-nonchimeras.fasta
# F483-nc	fasta	../2-chimera_detection/F483/F483-nonchimeras.fasta
# F484-nc	fasta	../2-chimera_detection/F484/F484-nonchimeras.fasta
# F485-nc	fasta	../2-chimera_detection/F485/F485-nonchimeras.fasta
# F486-nc	fasta	../2-chimera_detection/F486/F486-nonchimeras.fasta
# F487-nc	fasta	../2-chimera_detection/F487/F487-nonchimeras.fasta
# F488-nc	fasta	../2-chimera_detection/F488/F488-nonchimeras.fasta
# F489-nc	fasta	../2-chimera_detection/F489/F489-nonchimeras.fasta
# F49-nc	fasta	../2-chimera_detection/F49/F49-nonchimeras.fasta
# F490-nc	fasta	../2-chimera_detection/F490/F490-nonchimeras.fasta
# F491-nc	fasta	../2-chimera_detection/F491/F491-nonchimeras.fasta
# F492-nc	fasta	../2-chimera_detection/F492/F492-nonchimeras.fasta
# F493-nc	fasta	../2-chimera_detection/F493/F493-nonchimeras.fasta
# F494-nc	fasta	../2-chimera_detection/F494/F494-nonchimeras.fasta
# F495-nc	fasta	../2-chimera_detection/F495/F495-nonchimeras.fasta
# F496-nc	fasta	../2-chimera_detection/F496/F496-nonchimeras.fasta
# F497-nc	fasta	../2-chimera_detection/F497/F497-nonchimeras.fasta
# F498-nc	fasta	../2-chimera_detection/F498/F498-nonchimeras.fasta
# F499-nc	fasta	../2-chimera_detection/F499/F499-nonchimeras.fasta
# F5-nc	fasta	../2-chimera_detection/F5/F5-nonchimeras.fasta
# F50-nc	fasta	../2-chimera_detection/F50/F50-nonchimeras.fasta
# F500-nc	fasta	../2-chimera_detection/F500/F500-nonchimeras.fasta
# F501-nc	fasta	../2-chimera_detection/F501/F501-nonchimeras.fasta
# F502-nc	fasta	../2-chimera_detection/F502/F502-nonchimeras.fasta
# F503-nc	fasta	../2-chimera_detection/F503/F503-nonchimeras.fasta
# F504-nc	fasta	../2-chimera_detection/F504/F504-nonchimeras.fasta
# F505-nc	fasta	../2-chimera_detection/F505/F505-nonchimeras.fasta
# F506-nc	fasta	../2-chimera_detection/F506/F506-nonchimeras.fasta
# F507-nc	fasta	../2-chimera_detection/F507/F507-nonchimeras.fasta
# F508-nc	fasta	../2-chimera_detection/F508/F508-nonchimeras.fasta
# F51-nc	fasta	../2-chimera_detection/F51/F51-nonchimeras.fasta
# F52-nc	fasta	../2-chimera_detection/F52/F52-nonchimeras.fasta
# F53-nc	fasta	../2-chimera_detection/F53/F53-nonchimeras.fasta
# F54-nc	fasta	../2-chimera_detection/F54/F54-nonchimeras.fasta
# F55-nc	fasta	../2-chimera_detection/F55/F55-nonchimeras.fasta
# F56-nc	fasta	../2-chimera_detection/F56/F56-nonchimeras.fasta
# F57-nc	fasta	../2-chimera_detection/F57/F57-nonchimeras.fasta
# F58-nc	fasta	../2-chimera_detection/F58/F58-nonchimeras.fasta
# F59-nc	fasta	../2-chimera_detection/F59/F59-nonchimeras.fasta
# F6-nc	fasta	../2-chimera_detection/F6/F6-nonchimeras.fasta
# F60-nc	fasta	../2-chimera_detection/F60/F60-nonchimeras.fasta
# F61-nc	fasta	../2-chimera_detection/F61/F61-nonchimeras.fasta
# F62-nc	fasta	../2-chimera_detection/F62/F62-nonchimeras.fasta
# F63-nc	fasta	../2-chimera_detection/F63/F63-nonchimeras.fasta
# F64-nc	fasta	../2-chimera_detection/F64/F64-nonchimeras.fasta
# F65-nc	fasta	../2-chimera_detection/F65/F65-nonchimeras.fasta
# F66-nc	fasta	../2-chimera_detection/F66/F66-nonchimeras.fasta
# F67-nc	fasta	../2-chimera_detection/F67/F67-nonchimeras.fasta
# F68-nc	fasta	../2-chimera_detection/F68/F68-nonchimeras.fasta
# F69-nc	fasta	../2-chimera_detection/F69/F69-nonchimeras.fasta
# F7-nc	fasta	../2-chimera_detection/F7/F7-nonchimeras.fasta
# F70-nc	fasta	../2-chimera_detection/F70/F70-nonchimeras.fasta
# F71-nc	fasta	../2-chimera_detection/F71/F71-nonchimeras.fasta
# F72-nc	fasta	../2-chimera_detection/F72/F72-nonchimeras.fasta
# F73-nc	fasta	../2-chimera_detection/F73/F73-nonchimeras.fasta
# F74-nc	fasta	../2-chimera_detection/F74/F74-nonchimeras.fasta
# F75-nc	fasta	../2-chimera_detection/F75/F75-nonchimeras.fasta
# F76-nc	fasta	../2-chimera_detection/F76/F76-nonchimeras.fasta
# F77-nc	fasta	../2-chimera_detection/F77/F77-nonchimeras.fasta
# F78-nc	fasta	../2-chimera_detection/F78/F78-nonchimeras.fasta
# F79-nc	fasta	../2-chimera_detection/F79/F79-nonchimeras.fasta
# F8-nc	fasta	../2-chimera_detection/F8/F8-nonchimeras.fasta
# F80-nc	fasta	../2-chimera_detection/F80/F80-nonchimeras.fasta
# F81-nc	fasta	../2-chimera_detection/F81/F81-nonchimeras.fasta
# F82-nc	fasta	../2-chimera_detection/F82/F82-nonchimeras.fasta
# F83-nc	fasta	../2-chimera_detection/F83/F83-nonchimeras.fasta
# F84-nc	fasta	../2-chimera_detection/F84/F84-nonchimeras.fasta
# F85-nc	fasta	../2-chimera_detection/F85/F85-nonchimeras.fasta
# F86-nc	fasta	../2-chimera_detection/F86/F86-nonchimeras.fasta
# F87-nc	fasta	../2-chimera_detection/F87/F87-nonchimeras.fasta
# F88-nc	fasta	../2-chimera_detection/F88/F88-nonchimeras.fasta
# F89-nc	fasta	../2-chimera_detection/F89/F89-nonchimeras.fasta
# F9-nc	fasta	../2-chimera_detection/F9/F9-nonchimeras.fasta
# F90-nc	fasta	../2-chimera_detection/F90/F90-nonchimeras.fasta
# F91-nc	fasta	../2-chimera_detection/F91/F91-nonchimeras.fasta
# F92-nc	fasta	../2-chimera_detection/F92/F92-nonchimeras.fasta
# F93-nc	fasta	../2-chimera_detection/F93/F93-nonchimeras.fasta
# F94-nc	fasta	../2-chimera_detection/F94/F94-nonchimeras.fasta
# F95-nc	fasta	../2-chimera_detection/F95/F95-nonchimeras.fasta
# F96-nc	fasta	../2-chimera_detection/F96/F96-nonchimeras.fasta
# F97-nc	fasta	../2-chimera_detection/F97/F97-nonchimeras.fasta
# F98-nc	fasta	../2-chimera_detection/F98/F98-nonchimeras.fasta
# F99-nc	fasta	../2-chimera_detection/F99/F99-nonchimeras.fasta
# GLOBAL-nc	fasta	../2-chimera_detection/GLOBAL/GLOBAL-nonchimeras.fasta
# N10-1-nc	fasta	../2-chimera_detection/N10-1/N10-1-nonchimeras.fasta
# N10-2-nc	fasta	../2-chimera_detection/N10-2/N10-2-nonchimeras.fasta
# N10-3-nc	fasta	../2-chimera_detection/N10-3/N10-3-nonchimeras.fasta
# N10-4-nc	fasta	../2-chimera_detection/N10-4/N10-4-nonchimeras.fasta
# N10-5-nc	fasta	../2-chimera_detection/N10-5/N10-5-nonchimeras.fasta
# N10-6-nc	fasta	../2-chimera_detection/N10-6/N10-6-nonchimeras.fasta
# N1-1-nc	fasta	../2-chimera_detection/N1-1/N1-1-nonchimeras.fasta
# N11-1-nc	fasta	../2-chimera_detection/N11-1/N11-1-nonchimeras.fasta
# N11-2-nc	fasta	../2-chimera_detection/N11-2/N11-2-nonchimeras.fasta
# N11-3-nc	fasta	../2-chimera_detection/N11-3/N11-3-nonchimeras.fasta
# N11-4-nc	fasta	../2-chimera_detection/N11-4/N11-4-nonchimeras.fasta
# N11-5-nc	fasta	../2-chimera_detection/N11-5/N11-5-nonchimeras.fasta
# N11-6-nc	fasta	../2-chimera_detection/N11-6/N11-6-nonchimeras.fasta
# N1-2-nc	fasta	../2-chimera_detection/N1-2/N1-2-nonchimeras.fasta
# N12-1-nc	fasta	../2-chimera_detection/N12-1/N12-1-nonchimeras.fasta
# N12-2-nc	fasta	../2-chimera_detection/N12-2/N12-2-nonchimeras.fasta
# N12-3-nc	fasta	../2-chimera_detection/N12-3/N12-3-nonchimeras.fasta
# N12-4-nc	fasta	../2-chimera_detection/N12-4/N12-4-nonchimeras.fasta
# N12-5-nc	fasta	../2-chimera_detection/N12-5/N12-5-nonchimeras.fasta
# N12-6-nc	fasta	../2-chimera_detection/N12-6/N12-6-nonchimeras.fasta
# N1-3-nc	fasta	../2-chimera_detection/N1-3/N1-3-nonchimeras.fasta
# N13-1-nc	fasta	../2-chimera_detection/N13-1/N13-1-nonchimeras.fasta
# N13-2-nc	fasta	../2-chimera_detection/N13-2/N13-2-nonchimeras.fasta
# N13-3-nc	fasta	../2-chimera_detection/N13-3/N13-3-nonchimeras.fasta
# N13-4-nc	fasta	../2-chimera_detection/N13-4/N13-4-nonchimeras.fasta
# N13-5-nc	fasta	../2-chimera_detection/N13-5/N13-5-nonchimeras.fasta
# N13-6-nc	fasta	../2-chimera_detection/N13-6/N13-6-nonchimeras.fasta
# N1-4-nc	fasta	../2-chimera_detection/N1-4/N1-4-nonchimeras.fasta
# N14-1-nc	fasta	../2-chimera_detection/N14-1/N14-1-nonchimeras.fasta
# N14-2-nc	fasta	../2-chimera_detection/N14-2/N14-2-nonchimeras.fasta
# N14-3-nc	fasta	../2-chimera_detection/N14-3/N14-3-nonchimeras.fasta
# N14-4-nc	fasta	../2-chimera_detection/N14-4/N14-4-nonchimeras.fasta
# N14-5-nc	fasta	../2-chimera_detection/N14-5/N14-5-nonchimeras.fasta
# N14-6-nc	fasta	../2-chimera_detection/N14-6/N14-6-nonchimeras.fasta
# N1-5-nc	fasta	../2-chimera_detection/N1-5/N1-5-nonchimeras.fasta
# N15-1-nc	fasta	../2-chimera_detection/N15-1/N15-1-nonchimeras.fasta
# N15-2-nc	fasta	../2-chimera_detection/N15-2/N15-2-nonchimeras.fasta
# N15-3-nc	fasta	../2-chimera_detection/N15-3/N15-3-nonchimeras.fasta
# N15-4-nc	fasta	../2-chimera_detection/N15-4/N15-4-nonchimeras.fasta
# N15-5-nc	fasta	../2-chimera_detection/N15-5/N15-5-nonchimeras.fasta
# N15-6-nc	fasta	../2-chimera_detection/N15-6/N15-6-nonchimeras.fasta
# N1-6-nc	fasta	../2-chimera_detection/N1-6/N1-6-nonchimeras.fasta
# N16-1-nc	fasta	../2-chimera_detection/N16-1/N16-1-nonchimeras.fasta
# N16-2-nc	fasta	../2-chimera_detection/N16-2/N16-2-nonchimeras.fasta
# N16-3-nc	fasta	../2-chimera_detection/N16-3/N16-3-nonchimeras.fasta
# N16-4-nc	fasta	../2-chimera_detection/N16-4/N16-4-nonchimeras.fasta
# N16-5-nc	fasta	../2-chimera_detection/N16-5/N16-5-nonchimeras.fasta
# N16-6-nc	fasta	../2-chimera_detection/N16-6/N16-6-nonchimeras.fasta
# N17-1-nc	fasta	../2-chimera_detection/N17-1/N17-1-nonchimeras.fasta
# N17-2-nc	fasta	../2-chimera_detection/N17-2/N17-2-nonchimeras.fasta
# N17-3-nc	fasta	../2-chimera_detection/N17-3/N17-3-nonchimeras.fasta
# N17-4-nc	fasta	../2-chimera_detection/N17-4/N17-4-nonchimeras.fasta
# N17-5-nc	fasta	../2-chimera_detection/N17-5/N17-5-nonchimeras.fasta
# N17-6-nc	fasta	../2-chimera_detection/N17-6/N17-6-nonchimeras.fasta
# N18-1-nc	fasta	../2-chimera_detection/N18-1/N18-1-nonchimeras.fasta
# N18-2-nc	fasta	../2-chimera_detection/N18-2/N18-2-nonchimeras.fasta
# N18-3-nc	fasta	../2-chimera_detection/N18-3/N18-3-nonchimeras.fasta
# N18-4-nc	fasta	../2-chimera_detection/N18-4/N18-4-nonchimeras.fasta
# N18-5-nc	fasta	../2-chimera_detection/N18-5/N18-5-nonchimeras.fasta
# N18-6-nc	fasta	../2-chimera_detection/N18-6/N18-6-nonchimeras.fasta
# N19-1-nc	fasta	../2-chimera_detection/N19-1/N19-1-nonchimeras.fasta
# N19-2-nc	fasta	../2-chimera_detection/N19-2/N19-2-nonchimeras.fasta
# N19-3-nc	fasta	../2-chimera_detection/N19-3/N19-3-nonchimeras.fasta
# N19-4-nc	fasta	../2-chimera_detection/N19-4/N19-4-nonchimeras.fasta
# N19-5-nc	fasta	../2-chimera_detection/N19-5/N19-5-nonchimeras.fasta
# N19-6-nc	fasta	../2-chimera_detection/N19-6/N19-6-nonchimeras.fasta
# N2-1-nc	fasta	../2-chimera_detection/N2-1/N2-1-nonchimeras.fasta
# N2-2-nc	fasta	../2-chimera_detection/N2-2/N2-2-nonchimeras.fasta
# N2-3-nc	fasta	../2-chimera_detection/N2-3/N2-3-nonchimeras.fasta
# N2-4-nc	fasta	../2-chimera_detection/N2-4/N2-4-nonchimeras.fasta
# N2-5-nc	fasta	../2-chimera_detection/N2-5/N2-5-nonchimeras.fasta
# N2-6-nc	fasta	../2-chimera_detection/N2-6/N2-6-nonchimeras.fasta
# N3-1-nc	fasta	../2-chimera_detection/N3-1/N3-1-nonchimeras.fasta
# N3-2-nc	fasta	../2-chimera_detection/N3-2/N3-2-nonchimeras.fasta
# N3-3-nc	fasta	../2-chimera_detection/N3-3/N3-3-nonchimeras.fasta
# N3-4-nc	fasta	../2-chimera_detection/N3-4/N3-4-nonchimeras.fasta
# N3-5-nc	fasta	../2-chimera_detection/N3-5/N3-5-nonchimeras.fasta
# N3-6-nc	fasta	../2-chimera_detection/N3-6/N3-6-nonchimeras.fasta
# N4-1-nc	fasta	../2-chimera_detection/N4-1/N4-1-nonchimeras.fasta
# N4-2-nc	fasta	../2-chimera_detection/N4-2/N4-2-nonchimeras.fasta
# N4-3-nc	fasta	../2-chimera_detection/N4-3/N4-3-nonchimeras.fasta
# N4-4-nc	fasta	../2-chimera_detection/N4-4/N4-4-nonchimeras.fasta
# N4-5-nc	fasta	../2-chimera_detection/N4-5/N4-5-nonchimeras.fasta
# N4-6-nc	fasta	../2-chimera_detection/N4-6/N4-6-nonchimeras.fasta
# N5-1-nc	fasta	../2-chimera_detection/N5-1/N5-1-nonchimeras.fasta
# N5-2-nc	fasta	../2-chimera_detection/N5-2/N5-2-nonchimeras.fasta
# N5-3-nc	fasta	../2-chimera_detection/N5-3/N5-3-nonchimeras.fasta
# N5-4-nc	fasta	../2-chimera_detection/N5-4/N5-4-nonchimeras.fasta
# N5-5-nc	fasta	../2-chimera_detection/N5-5/N5-5-nonchimeras.fasta
# N5-6-nc	fasta	../2-chimera_detection/N5-6/N5-6-nonchimeras.fasta
# N6-1-nc	fasta	../2-chimera_detection/N6-1/N6-1-nonchimeras.fasta
# N6-2-nc	fasta	../2-chimera_detection/N6-2/N6-2-nonchimeras.fasta
# N6-3-nc	fasta	../2-chimera_detection/N6-3/N6-3-nonchimeras.fasta
# N6-4-nc	fasta	../2-chimera_detection/N6-4/N6-4-nonchimeras.fasta
# N6-5-nc	fasta	../2-chimera_detection/N6-5/N6-5-nonchimeras.fasta
# N6-6-nc	fasta	../2-chimera_detection/N6-6/N6-6-nonchimeras.fasta
# N7-1-nc	fasta	../2-chimera_detection/N7-1/N7-1-nonchimeras.fasta
# N7-2-nc	fasta	../2-chimera_detection/N7-2/N7-2-nonchimeras.fasta
# N7-3-nc	fasta	../2-chimera_detection/N7-3/N7-3-nonchimeras.fasta
# N7-4-nc	fasta	../2-chimera_detection/N7-4/N7-4-nonchimeras.fasta
# N7-5-nc	fasta	../2-chimera_detection/N7-5/N7-5-nonchimeras.fasta
# N7-6-nc	fasta	../2-chimera_detection/N7-6/N7-6-nonchimeras.fasta
# N8-1-nc	fasta	../2-chimera_detection/N8-1/N8-1-nonchimeras.fasta
# N8-2-nc	fasta	../2-chimera_detection/N8-2/N8-2-nonchimeras.fasta
# N8-3-nc	fasta	../2-chimera_detection/N8-3/N8-3-nonchimeras.fasta
# N8-4-nc	fasta	../2-chimera_detection/N8-4/N8-4-nonchimeras.fasta
# N8-5-nc	fasta	../2-chimera_detection/N8-5/N8-5-nonchimeras.fasta
# N8-6-nc	fasta	../2-chimera_detection/N8-6/N8-6-nonchimeras.fasta
# N9-1-nc	fasta	../2-chimera_detection/N9-1/N9-1-nonchimeras.fasta
# N9-2-nc	fasta	../2-chimera_detection/N9-2/N9-2-nonchimeras.fasta
# N9-3-nc	fasta	../2-chimera_detection/N9-3/N9-3-nonchimeras.fasta
# N9-4-nc	fasta	../2-chimera_detection/N9-4/N9-4-nonchimeras.fasta
# N9-5-nc	fasta	../2-chimera_detection/N9-5/N9-5-nonchimeras.fasta
# N9-6-nc	fasta	../2-chimera_detection/N9-6/N9-6-nonchimeras.fasta
# NU1-nc	fasta	../2-chimera_detection/NU1/NU1-nonchimeras.fasta
# NU10-nc	fasta	../2-chimera_detection/NU10/NU10-nonchimeras.fasta
# NU11-nc	fasta	../2-chimera_detection/NU11/NU11-nonchimeras.fasta
# NU12-nc	fasta	../2-chimera_detection/NU12/NU12-nonchimeras.fasta
# NU13-nc	fasta	../2-chimera_detection/NU13/NU13-nonchimeras.fasta
# NU14-nc	fasta	../2-chimera_detection/NU14/NU14-nonchimeras.fasta
# NU15-nc	fasta	../2-chimera_detection/NU15/NU15-nonchimeras.fasta
# NU16-nc	fasta	../2-chimera_detection/NU16/NU16-nonchimeras.fasta
# NU17-nc	fasta	../2-chimera_detection/NU17/NU17-nonchimeras.fasta
# NU18-nc	fasta	../2-chimera_detection/NU18/NU18-nonchimeras.fasta
# NU19-nc	fasta	../2-chimera_detection/NU19/NU19-nonchimeras.fasta
# NU2-nc	fasta	../2-chimera_detection/NU2/NU2-nonchimeras.fasta
# NU20-nc	fasta	../2-chimera_detection/NU20/NU20-nonchimeras.fasta
# NU21-nc	fasta	../2-chimera_detection/NU21/NU21-nonchimeras.fasta
# NU22-nc	fasta	../2-chimera_detection/NU22/NU22-nonchimeras.fasta
# NU23-nc	fasta	../2-chimera_detection/NU23/NU23-nonchimeras.fasta
# NU24-nc	fasta	../2-chimera_detection/NU24/NU24-nonchimeras.fasta
# NU3-nc	fasta	../2-chimera_detection/NU3/NU3-nonchimeras.fasta
# NU4-nc	fasta	../2-chimera_detection/NU4/NU4-nonchimeras.fasta
# NU5-nc	fasta	../2-chimera_detection/NU5/NU5-nonchimeras.fasta
# NU6-nc	fasta	../2-chimera_detection/NU6/NU6-nonchimeras.fasta
# NU7-nc	fasta	../2-chimera_detection/NU7/NU7-nonchimeras.fasta
# NU8-nc	fasta	../2-chimera_detection/NU8/NU8-nonchimeras.fasta
# NU9-nc	fasta	../2-chimera_detection/NU9/NU9-nonchimeras.fasta
# P10-1-nc	fasta	../2-chimera_detection/P10-1/P10-1-nonchimeras.fasta
# P10-2-nc	fasta	../2-chimera_detection/P10-2/P10-2-nonchimeras.fasta
# P10-3-nc	fasta	../2-chimera_detection/P10-3/P10-3-nonchimeras.fasta
# P10-4-nc	fasta	../2-chimera_detection/P10-4/P10-4-nonchimeras.fasta
# P10-5-nc	fasta	../2-chimera_detection/P10-5/P10-5-nonchimeras.fasta
# P10-6-nc	fasta	../2-chimera_detection/P10-6/P10-6-nonchimeras.fasta
# P1-1-nc	fasta	../2-chimera_detection/P1-1/P1-1-nonchimeras.fasta
# P11-1-nc	fasta	../2-chimera_detection/P11-1/P11-1-nonchimeras.fasta
# P11-2-nc	fasta	../2-chimera_detection/P11-2/P11-2-nonchimeras.fasta
# P11-3-nc	fasta	../2-chimera_detection/P11-3/P11-3-nonchimeras.fasta
# P11-4-nc	fasta	../2-chimera_detection/P11-4/P11-4-nonchimeras.fasta
# P11-5-nc	fasta	../2-chimera_detection/P11-5/P11-5-nonchimeras.fasta
# P11-6-nc	fasta	../2-chimera_detection/P11-6/P11-6-nonchimeras.fasta
# P1-2-nc	fasta	../2-chimera_detection/P1-2/P1-2-nonchimeras.fasta
# P12-1-nc	fasta	../2-chimera_detection/P12-1/P12-1-nonchimeras.fasta
# P12-2-nc	fasta	../2-chimera_detection/P12-2/P12-2-nonchimeras.fasta
# P12-3-nc	fasta	../2-chimera_detection/P12-3/P12-3-nonchimeras.fasta
# P12-4-nc	fasta	../2-chimera_detection/P12-4/P12-4-nonchimeras.fasta
# P12-5-nc	fasta	../2-chimera_detection/P12-5/P12-5-nonchimeras.fasta
# P12-6-nc	fasta	../2-chimera_detection/P12-6/P12-6-nonchimeras.fasta
# P1-3-nc	fasta	../2-chimera_detection/P1-3/P1-3-nonchimeras.fasta
# P13-1-nc	fasta	../2-chimera_detection/P13-1/P13-1-nonchimeras.fasta
# P13-2-nc	fasta	../2-chimera_detection/P13-2/P13-2-nonchimeras.fasta
# P13-3-nc	fasta	../2-chimera_detection/P13-3/P13-3-nonchimeras.fasta
# P13-4-nc	fasta	../2-chimera_detection/P13-4/P13-4-nonchimeras.fasta
# P13-5-nc	fasta	../2-chimera_detection/P13-5/P13-5-nonchimeras.fasta
# P13-6-nc	fasta	../2-chimera_detection/P13-6/P13-6-nonchimeras.fasta
# P1-4-nc	fasta	../2-chimera_detection/P1-4/P1-4-nonchimeras.fasta
# P14-1-nc	fasta	../2-chimera_detection/P14-1/P14-1-nonchimeras.fasta
# P14-2-nc	fasta	../2-chimera_detection/P14-2/P14-2-nonchimeras.fasta
# P14-3-nc	fasta	../2-chimera_detection/P14-3/P14-3-nonchimeras.fasta
# P14-4-nc	fasta	../2-chimera_detection/P14-4/P14-4-nonchimeras.fasta
# P14-5-nc	fasta	../2-chimera_detection/P14-5/P14-5-nonchimeras.fasta
# P14-6-nc	fasta	../2-chimera_detection/P14-6/P14-6-nonchimeras.fasta
# P1-5-nc	fasta	../2-chimera_detection/P1-5/P1-5-nonchimeras.fasta
# P15-1-nc	fasta	../2-chimera_detection/P15-1/P15-1-nonchimeras.fasta
# P15-2-nc	fasta	../2-chimera_detection/P15-2/P15-2-nonchimeras.fasta
# P15-3-nc	fasta	../2-chimera_detection/P15-3/P15-3-nonchimeras.fasta
# P15-4-nc	fasta	../2-chimera_detection/P15-4/P15-4-nonchimeras.fasta
# P15-5-nc	fasta	../2-chimera_detection/P15-5/P15-5-nonchimeras.fasta
# P15-6-nc	fasta	../2-chimera_detection/P15-6/P15-6-nonchimeras.fasta
# P1-6-nc	fasta	../2-chimera_detection/P1-6/P1-6-nonchimeras.fasta
# P16-1-nc	fasta	../2-chimera_detection/P16-1/P16-1-nonchimeras.fasta
# P16-2-nc	fasta	../2-chimera_detection/P16-2/P16-2-nonchimeras.fasta
# P16-3-nc	fasta	../2-chimera_detection/P16-3/P16-3-nonchimeras.fasta
# P16-4-nc	fasta	../2-chimera_detection/P16-4/P16-4-nonchimeras.fasta
# P16-5-nc	fasta	../2-chimera_detection/P16-5/P16-5-nonchimeras.fasta
# P16-6-nc	fasta	../2-chimera_detection/P16-6/P16-6-nonchimeras.fasta
# P17-1-nc	fasta	../2-chimera_detection/P17-1/P17-1-nonchimeras.fasta
# P17-2-nc	fasta	../2-chimera_detection/P17-2/P17-2-nonchimeras.fasta
# P17-3-nc	fasta	../2-chimera_detection/P17-3/P17-3-nonchimeras.fasta
# P17-4-nc	fasta	../2-chimera_detection/P17-4/P17-4-nonchimeras.fasta
# P17-5-nc	fasta	../2-chimera_detection/P17-5/P17-5-nonchimeras.fasta
# P17-6-nc	fasta	../2-chimera_detection/P17-6/P17-6-nonchimeras.fasta
# P18-1-nc	fasta	../2-chimera_detection/P18-1/P18-1-nonchimeras.fasta
# P18-2-nc	fasta	../2-chimera_detection/P18-2/P18-2-nonchimeras.fasta
# P18-3-nc	fasta	../2-chimera_detection/P18-3/P18-3-nonchimeras.fasta
# P18-4-nc	fasta	../2-chimera_detection/P18-4/P18-4-nonchimeras.fasta
# P18-5-nc	fasta	../2-chimera_detection/P18-5/P18-5-nonchimeras.fasta
# P18-6-nc	fasta	../2-chimera_detection/P18-6/P18-6-nonchimeras.fasta
# P19-1-nc	fasta	../2-chimera_detection/P19-1/P19-1-nonchimeras.fasta
# P19-2-nc	fasta	../2-chimera_detection/P19-2/P19-2-nonchimeras.fasta
# P19-3-nc	fasta	../2-chimera_detection/P19-3/P19-3-nonchimeras.fasta
# P19-4-nc	fasta	../2-chimera_detection/P19-4/P19-4-nonchimeras.fasta
# P19-5-nc	fasta	../2-chimera_detection/P19-5/P19-5-nonchimeras.fasta
# P19-6-nc	fasta	../2-chimera_detection/P19-6/P19-6-nonchimeras.fasta
# P2-1-nc	fasta	../2-chimera_detection/P2-1/P2-1-nonchimeras.fasta
# P2-2-nc	fasta	../2-chimera_detection/P2-2/P2-2-nonchimeras.fasta
# P2-3-nc	fasta	../2-chimera_detection/P2-3/P2-3-nonchimeras.fasta
# P2-4-nc	fasta	../2-chimera_detection/P2-4/P2-4-nonchimeras.fasta
# P2-5-nc	fasta	../2-chimera_detection/P2-5/P2-5-nonchimeras.fasta
# P2-6-nc	fasta	../2-chimera_detection/P2-6/P2-6-nonchimeras.fasta
# P3-1-nc	fasta	../2-chimera_detection/P3-1/P3-1-nonchimeras.fasta
# P3-2-nc	fasta	../2-chimera_detection/P3-2/P3-2-nonchimeras.fasta
# P3-3-nc	fasta	../2-chimera_detection/P3-3/P3-3-nonchimeras.fasta
# P3-4-nc	fasta	../2-chimera_detection/P3-4/P3-4-nonchimeras.fasta
# P3-5-nc	fasta	../2-chimera_detection/P3-5/P3-5-nonchimeras.fasta
# P3-6-nc	fasta	../2-chimera_detection/P3-6/P3-6-nonchimeras.fasta
# P4-1-nc	fasta	../2-chimera_detection/P4-1/P4-1-nonchimeras.fasta
# P4-2-nc	fasta	../2-chimera_detection/P4-2/P4-2-nonchimeras.fasta
# P4-3-nc	fasta	../2-chimera_detection/P4-3/P4-3-nonchimeras.fasta
# P4-4-nc	fasta	../2-chimera_detection/P4-4/P4-4-nonchimeras.fasta
# P4-5-nc	fasta	../2-chimera_detection/P4-5/P4-5-nonchimeras.fasta
# P4-6-nc	fasta	../2-chimera_detection/P4-6/P4-6-nonchimeras.fasta
# P5-1-nc	fasta	../2-chimera_detection/P5-1/P5-1-nonchimeras.fasta
# P5-2-nc	fasta	../2-chimera_detection/P5-2/P5-2-nonchimeras.fasta
# P5-3-nc	fasta	../2-chimera_detection/P5-3/P5-3-nonchimeras.fasta
# P5-4-nc	fasta	../2-chimera_detection/P5-4/P5-4-nonchimeras.fasta
# P5-5-nc	fasta	../2-chimera_detection/P5-5/P5-5-nonchimeras.fasta
# P5-6-nc	fasta	../2-chimera_detection/P5-6/P5-6-nonchimeras.fasta
# P6-1-nc	fasta	../2-chimera_detection/P6-1/P6-1-nonchimeras.fasta
# P6-2-nc	fasta	../2-chimera_detection/P6-2/P6-2-nonchimeras.fasta
# P6-3-nc	fasta	../2-chimera_detection/P6-3/P6-3-nonchimeras.fasta
# P6-4-nc	fasta	../2-chimera_detection/P6-4/P6-4-nonchimeras.fasta
# P6-5-nc	fasta	../2-chimera_detection/P6-5/P6-5-nonchimeras.fasta
# P6-6-nc	fasta	../2-chimera_detection/P6-6/P6-6-nonchimeras.fasta
# P7-1-nc	fasta	../2-chimera_detection/P7-1/P7-1-nonchimeras.fasta
# P7-2-nc	fasta	../2-chimera_detection/P7-2/P7-2-nonchimeras.fasta
# P7-3-nc	fasta	../2-chimera_detection/P7-3/P7-3-nonchimeras.fasta
# P7-4-nc	fasta	../2-chimera_detection/P7-4/P7-4-nonchimeras.fasta
# P7-5-nc	fasta	../2-chimera_detection/P7-5/P7-5-nonchimeras.fasta
# P7-6-nc	fasta	../2-chimera_detection/P7-6/P7-6-nonchimeras.fasta
# P8-1-nc	fasta	../2-chimera_detection/P8-1/P8-1-nonchimeras.fasta
# P8-2-nc	fasta	../2-chimera_detection/P8-2/P8-2-nonchimeras.fasta
# P8-3-nc	fasta	../2-chimera_detection/P8-3/P8-3-nonchimeras.fasta
# P8-4-nc	fasta	../2-chimera_detection/P8-4/P8-4-nonchimeras.fasta
# P8-5-nc	fasta	../2-chimera_detection/P8-5/P8-5-nonchimeras.fasta
# P8-6-nc	fasta	../2-chimera_detection/P8-6/P8-6-nonchimeras.fasta
# P9-1-nc	fasta	../2-chimera_detection/P9-1/P9-1-nonchimeras.fasta
# P9-2-nc	fasta	../2-chimera_detection/P9-2/P9-2-nonchimeras.fasta
# P9-3-nc	fasta	../2-chimera_detection/P9-3/P9-3-nonchimeras.fasta
# P9-4-nc	fasta	../2-chimera_detection/P9-4/P9-4-nonchimeras.fasta
# P9-5-nc	fasta	../2-chimera_detection/P9-5/P9-5-nonchimeras.fasta
# P9-6-nc	fasta	../2-chimera_detection/P9-6/P9-6-nonchimeras.fasta

# %% [markdown]
# The `Querymap.txt` file has been made but includes the `./GLOBAL` directory in which all centroids and queries are contained (line 514). This will cause metaBEAT to fail so it must be removed manually from the `Querymap.txt` file.

# %%
# !sed '/GLOBAL/d' Querymap.txt > Querymap_final.txt

# %%
# !cat Querymap_final.txt
# Out:
# F1-nc	fasta	../2-chimera_detection/F1/F1-nonchimeras.fasta
# F10-nc	fasta	../2-chimera_detection/F10/F10-nonchimeras.fasta
# F100-nc	fasta	../2-chimera_detection/F100/F100-nonchimeras.fasta
# F101-nc	fasta	../2-chimera_detection/F101/F101-nonchimeras.fasta
# F102-nc	fasta	../2-chimera_detection/F102/F102-nonchimeras.fasta
# F103-nc	fasta	../2-chimera_detection/F103/F103-nonchimeras.fasta
# F104-nc	fasta	../2-chimera_detection/F104/F104-nonchimeras.fasta
# F105-nc	fasta	../2-chimera_detection/F105/F105-nonchimeras.fasta
# F106-nc	fasta	../2-chimera_detection/F106/F106-nonchimeras.fasta
# F107-nc	fasta	../2-chimera_detection/F107/F107-nonchimeras.fasta
# F108-nc	fasta	../2-chimera_detection/F108/F108-nonchimeras.fasta
# F109-nc	fasta	../2-chimera_detection/F109/F109-nonchimeras.fasta
# F11-nc	fasta	../2-chimera_detection/F11/F11-nonchimeras.fasta
# F110-nc	fasta	../2-chimera_detection/F110/F110-nonchimeras.fasta
# F111-nc	fasta	../2-chimera_detection/F111/F111-nonchimeras.fasta
# F112-nc	fasta	../2-chimera_detection/F112/F112-nonchimeras.fasta
# F113-nc	fasta	../2-chimera_detection/F113/F113-nonchimeras.fasta
# F114-nc	fasta	../2-chimera_detection/F114/F114-nonchimeras.fasta
# F115-nc	fasta	../2-chimera_detection/F115/F115-nonchimeras.fasta
# F116-nc	fasta	../2-chimera_detection/F116/F116-nonchimeras.fasta
# F117-nc	fasta	../2-chimera_detection/F117/F117-nonchimeras.fasta
# F118-nc	fasta	../2-chimera_detection/F118/F118-nonchimeras.fasta
# F119-nc	fasta	../2-chimera_detection/F119/F119-nonchimeras.fasta
# F12-nc	fasta	../2-chimera_detection/F12/F12-nonchimeras.fasta
# F120-nc	fasta	../2-chimera_detection/F120/F120-nonchimeras.fasta
# F121-nc	fasta	../2-chimera_detection/F121/F121-nonchimeras.fasta
# F122-nc	fasta	../2-chimera_detection/F122/F122-nonchimeras.fasta
# F123-nc	fasta	../2-chimera_detection/F123/F123-nonchimeras.fasta
# F124-nc	fasta	../2-chimera_detection/F124/F124-nonchimeras.fasta
# F125-nc	fasta	../2-chimera_detection/F125/F125-nonchimeras.fasta
# F126-nc	fasta	../2-chimera_detection/F126/F126-nonchimeras.fasta
# F127-nc	fasta	../2-chimera_detection/F127/F127-nonchimeras.fasta
# F128-nc	fasta	../2-chimera_detection/F128/F128-nonchimeras.fasta
# F129-nc	fasta	../2-chimera_detection/F129/F129-nonchimeras.fasta
# F13-nc	fasta	../2-chimera_detection/F13/F13-nonchimeras.fasta
# F130-nc	fasta	../2-chimera_detection/F130/F130-nonchimeras.fasta
# F131-nc	fasta	../2-chimera_detection/F131/F131-nonchimeras.fasta
# F132-nc	fasta	../2-chimera_detection/F132/F132-nonchimeras.fasta
# F133-nc	fasta	../2-chimera_detection/F133/F133-nonchimeras.fasta
# F134-nc	fasta	../2-chimera_detection/F134/F134-nonchimeras.fasta
# F135-nc	fasta	../2-chimera_detection/F135/F135-nonchimeras.fasta
# F136-nc	fasta	../2-chimera_detection/F136/F136-nonchimeras.fasta
# F137-nc	fasta	../2-chimera_detection/F137/F137-nonchimeras.fasta
# F138-nc	fasta	../2-chimera_detection/F138/F138-nonchimeras.fasta
# F139-nc	fasta	../2-chimera_detection/F139/F139-nonchimeras.fasta
# F14-nc	fasta	../2-chimera_detection/F14/F14-nonchimeras.fasta
# F140-nc	fasta	../2-chimera_detection/F140/F140-nonchimeras.fasta
# F141-nc	fasta	../2-chimera_detection/F141/F141-nonchimeras.fasta
# F142-nc	fasta	../2-chimera_detection/F142/F142-nonchimeras.fasta
# F143-nc	fasta	../2-chimera_detection/F143/F143-nonchimeras.fasta
# F144-nc	fasta	../2-chimera_detection/F144/F144-nonchimeras.fasta
# F145-nc	fasta	../2-chimera_detection/F145/F145-nonchimeras.fasta
# F146-nc	fasta	../2-chimera_detection/F146/F146-nonchimeras.fasta
# F147-nc	fasta	../2-chimera_detection/F147/F147-nonchimeras.fasta
# F148-nc	fasta	../2-chimera_detection/F148/F148-nonchimeras.fasta
# F149-nc	fasta	../2-chimera_detection/F149/F149-nonchimeras.fasta
# F15-nc	fasta	../2-chimera_detection/F15/F15-nonchimeras.fasta
# F150-nc	fasta	../2-chimera_detection/F150/F150-nonchimeras.fasta
# F151-nc	fasta	../2-chimera_detection/F151/F151-nonchimeras.fasta
# F152-nc	fasta	../2-chimera_detection/F152/F152-nonchimeras.fasta
# F153-nc	fasta	../2-chimera_detection/F153/F153-nonchimeras.fasta
# F154-nc	fasta	../2-chimera_detection/F154/F154-nonchimeras.fasta
# F155-nc	fasta	../2-chimera_detection/F155/F155-nonchimeras.fasta
# F156-nc	fasta	../2-chimera_detection/F156/F156-nonchimeras.fasta
# F157-nc	fasta	../2-chimera_detection/F157/F157-nonchimeras.fasta
# F158-nc	fasta	../2-chimera_detection/F158/F158-nonchimeras.fasta
# F159-nc	fasta	../2-chimera_detection/F159/F159-nonchimeras.fasta
# F16-nc	fasta	../2-chimera_detection/F16/F16-nonchimeras.fasta
# F160-nc	fasta	../2-chimera_detection/F160/F160-nonchimeras.fasta
# F161-nc	fasta	../2-chimera_detection/F161/F161-nonchimeras.fasta
# F162-nc	fasta	../2-chimera_detection/F162/F162-nonchimeras.fasta
# F163-nc	fasta	../2-chimera_detection/F163/F163-nonchimeras.fasta
# F164-nc	fasta	../2-chimera_detection/F164/F164-nonchimeras.fasta
# F165-nc	fasta	../2-chimera_detection/F165/F165-nonchimeras.fasta
# F166-nc	fasta	../2-chimera_detection/F166/F166-nonchimeras.fasta
# F167-nc	fasta	../2-chimera_detection/F167/F167-nonchimeras.fasta
# F168-nc	fasta	../2-chimera_detection/F168/F168-nonchimeras.fasta
# F169-nc	fasta	../2-chimera_detection/F169/F169-nonchimeras.fasta
# F17-nc	fasta	../2-chimera_detection/F17/F17-nonchimeras.fasta
# F170-nc	fasta	../2-chimera_detection/F170/F170-nonchimeras.fasta
# F171-nc	fasta	../2-chimera_detection/F171/F171-nonchimeras.fasta
# F172-nc	fasta	../2-chimera_detection/F172/F172-nonchimeras.fasta
# F173-nc	fasta	../2-chimera_detection/F173/F173-nonchimeras.fasta
# F174-nc	fasta	../2-chimera_detection/F174/F174-nonchimeras.fasta
# F175-nc	fasta	../2-chimera_detection/F175/F175-nonchimeras.fasta
# F176-nc	fasta	../2-chimera_detection/F176/F176-nonchimeras.fasta
# F177-nc	fasta	../2-chimera_detection/F177/F177-nonchimeras.fasta
# F178-nc	fasta	../2-chimera_detection/F178/F178-nonchimeras.fasta
# F179-nc	fasta	../2-chimera_detection/F179/F179-nonchimeras.fasta
# F18-nc	fasta	../2-chimera_detection/F18/F18-nonchimeras.fasta
# F180-nc	fasta	../2-chimera_detection/F180/F180-nonchimeras.fasta
# F181-nc	fasta	../2-chimera_detection/F181/F181-nonchimeras.fasta
# F182-nc	fasta	../2-chimera_detection/F182/F182-nonchimeras.fasta
# F183-nc	fasta	../2-chimera_detection/F183/F183-nonchimeras.fasta
# F184-nc	fasta	../2-chimera_detection/F184/F184-nonchimeras.fasta
# F185-nc	fasta	../2-chimera_detection/F185/F185-nonchimeras.fasta
# F186-nc	fasta	../2-chimera_detection/F186/F186-nonchimeras.fasta
# F187-nc	fasta	../2-chimera_detection/F187/F187-nonchimeras.fasta
# F188-nc	fasta	../2-chimera_detection/F188/F188-nonchimeras.fasta
# F189-nc	fasta	../2-chimera_detection/F189/F189-nonchimeras.fasta
# F19-nc	fasta	../2-chimera_detection/F19/F19-nonchimeras.fasta
# F190-nc	fasta	../2-chimera_detection/F190/F190-nonchimeras.fasta
# F191-nc	fasta	../2-chimera_detection/F191/F191-nonchimeras.fasta
# F192-nc	fasta	../2-chimera_detection/F192/F192-nonchimeras.fasta
# F193-nc	fasta	../2-chimera_detection/F193/F193-nonchimeras.fasta
# F194-nc	fasta	../2-chimera_detection/F194/F194-nonchimeras.fasta
# F195-nc	fasta	../2-chimera_detection/F195/F195-nonchimeras.fasta
# F196-nc	fasta	../2-chimera_detection/F196/F196-nonchimeras.fasta
# F197-nc	fasta	../2-chimera_detection/F197/F197-nonchimeras.fasta
# F198-nc	fasta	../2-chimera_detection/F198/F198-nonchimeras.fasta
# F199-nc	fasta	../2-chimera_detection/F199/F199-nonchimeras.fasta
# F2-nc	fasta	../2-chimera_detection/F2/F2-nonchimeras.fasta
# F20-nc	fasta	../2-chimera_detection/F20/F20-nonchimeras.fasta
# F200-nc	fasta	../2-chimera_detection/F200/F200-nonchimeras.fasta
# F201-nc	fasta	../2-chimera_detection/F201/F201-nonchimeras.fasta
# F202-nc	fasta	../2-chimera_detection/F202/F202-nonchimeras.fasta
# F203-nc	fasta	../2-chimera_detection/F203/F203-nonchimeras.fasta
# F204-nc	fasta	../2-chimera_detection/F204/F204-nonchimeras.fasta
# F205-nc	fasta	../2-chimera_detection/F205/F205-nonchimeras.fasta
# F206-nc	fasta	../2-chimera_detection/F206/F206-nonchimeras.fasta
# F207-nc	fasta	../2-chimera_detection/F207/F207-nonchimeras.fasta
# F208-nc	fasta	../2-chimera_detection/F208/F208-nonchimeras.fasta
# F209-nc	fasta	../2-chimera_detection/F209/F209-nonchimeras.fasta
# F21-nc	fasta	../2-chimera_detection/F21/F21-nonchimeras.fasta
# F210-nc	fasta	../2-chimera_detection/F210/F210-nonchimeras.fasta
# F211-nc	fasta	../2-chimera_detection/F211/F211-nonchimeras.fasta
# F212-nc	fasta	../2-chimera_detection/F212/F212-nonchimeras.fasta
# F213-nc	fasta	../2-chimera_detection/F213/F213-nonchimeras.fasta
# F214-nc	fasta	../2-chimera_detection/F214/F214-nonchimeras.fasta
# F215-nc	fasta	../2-chimera_detection/F215/F215-nonchimeras.fasta
# F216-nc	fasta	../2-chimera_detection/F216/F216-nonchimeras.fasta
# F217-nc	fasta	../2-chimera_detection/F217/F217-nonchimeras.fasta
# F218-nc	fasta	../2-chimera_detection/F218/F218-nonchimeras.fasta
# F219-nc	fasta	../2-chimera_detection/F219/F219-nonchimeras.fasta
# F22-nc	fasta	../2-chimera_detection/F22/F22-nonchimeras.fasta
# F220-nc	fasta	../2-chimera_detection/F220/F220-nonchimeras.fasta
# F221-nc	fasta	../2-chimera_detection/F221/F221-nonchimeras.fasta
# F222-nc	fasta	../2-chimera_detection/F222/F222-nonchimeras.fasta
# F223-nc	fasta	../2-chimera_detection/F223/F223-nonchimeras.fasta
# F224-nc	fasta	../2-chimera_detection/F224/F224-nonchimeras.fasta
# F225-nc	fasta	../2-chimera_detection/F225/F225-nonchimeras.fasta
# F226-nc	fasta	../2-chimera_detection/F226/F226-nonchimeras.fasta
# F227-nc	fasta	../2-chimera_detection/F227/F227-nonchimeras.fasta
# F228-nc	fasta	../2-chimera_detection/F228/F228-nonchimeras.fasta
# F229-nc	fasta	../2-chimera_detection/F229/F229-nonchimeras.fasta
# F23-nc	fasta	../2-chimera_detection/F23/F23-nonchimeras.fasta
# F230-nc	fasta	../2-chimera_detection/F230/F230-nonchimeras.fasta
# F231-nc	fasta	../2-chimera_detection/F231/F231-nonchimeras.fasta
# F232-nc	fasta	../2-chimera_detection/F232/F232-nonchimeras.fasta
# F233-nc	fasta	../2-chimera_detection/F233/F233-nonchimeras.fasta
# F234-nc	fasta	../2-chimera_detection/F234/F234-nonchimeras.fasta
# F235-nc	fasta	../2-chimera_detection/F235/F235-nonchimeras.fasta
# F236-nc	fasta	../2-chimera_detection/F236/F236-nonchimeras.fasta
# F237-nc	fasta	../2-chimera_detection/F237/F237-nonchimeras.fasta
# F238-nc	fasta	../2-chimera_detection/F238/F238-nonchimeras.fasta
# F239-nc	fasta	../2-chimera_detection/F239/F239-nonchimeras.fasta
# F24-nc	fasta	../2-chimera_detection/F24/F24-nonchimeras.fasta
# F240-nc	fasta	../2-chimera_detection/F240/F240-nonchimeras.fasta
# F241-nc	fasta	../2-chimera_detection/F241/F241-nonchimeras.fasta
# F242-nc	fasta	../2-chimera_detection/F242/F242-nonchimeras.fasta
# F243-nc	fasta	../2-chimera_detection/F243/F243-nonchimeras.fasta
# F244-nc	fasta	../2-chimera_detection/F244/F244-nonchimeras.fasta
# F245-nc	fasta	../2-chimera_detection/F245/F245-nonchimeras.fasta
# F246-nc	fasta	../2-chimera_detection/F246/F246-nonchimeras.fasta
# F247-nc	fasta	../2-chimera_detection/F247/F247-nonchimeras.fasta
# F248-nc	fasta	../2-chimera_detection/F248/F248-nonchimeras.fasta
# F249-nc	fasta	../2-chimera_detection/F249/F249-nonchimeras.fasta
# F25-nc	fasta	../2-chimera_detection/F25/F25-nonchimeras.fasta
# F250-nc	fasta	../2-chimera_detection/F250/F250-nonchimeras.fasta
# F251-nc	fasta	../2-chimera_detection/F251/F251-nonchimeras.fasta
# F252-nc	fasta	../2-chimera_detection/F252/F252-nonchimeras.fasta
# F253-nc	fasta	../2-chimera_detection/F253/F253-nonchimeras.fasta
# F254-nc	fasta	../2-chimera_detection/F254/F254-nonchimeras.fasta
# F255-nc	fasta	../2-chimera_detection/F255/F255-nonchimeras.fasta
# F256-nc	fasta	../2-chimera_detection/F256/F256-nonchimeras.fasta
# F257-nc	fasta	../2-chimera_detection/F257/F257-nonchimeras.fasta
# F258-nc	fasta	../2-chimera_detection/F258/F258-nonchimeras.fasta
# F259-nc	fasta	../2-chimera_detection/F259/F259-nonchimeras.fasta
# F26-nc	fasta	../2-chimera_detection/F26/F26-nonchimeras.fasta
# F260-nc	fasta	../2-chimera_detection/F260/F260-nonchimeras.fasta
# F261-nc	fasta	../2-chimera_detection/F261/F261-nonchimeras.fasta
# F262-nc	fasta	../2-chimera_detection/F262/F262-nonchimeras.fasta
# F263-nc	fasta	../2-chimera_detection/F263/F263-nonchimeras.fasta
# F264-nc	fasta	../2-chimera_detection/F264/F264-nonchimeras.fasta
# F265-nc	fasta	../2-chimera_detection/F265/F265-nonchimeras.fasta
# F266-nc	fasta	../2-chimera_detection/F266/F266-nonchimeras.fasta
# F267-nc	fasta	../2-chimera_detection/F267/F267-nonchimeras.fasta
# F268-nc	fasta	../2-chimera_detection/F268/F268-nonchimeras.fasta
# F269-nc	fasta	../2-chimera_detection/F269/F269-nonchimeras.fasta
# F27-nc	fasta	../2-chimera_detection/F27/F27-nonchimeras.fasta
# F270-nc	fasta	../2-chimera_detection/F270/F270-nonchimeras.fasta
# F271-nc	fasta	../2-chimera_detection/F271/F271-nonchimeras.fasta
# F272-nc	fasta	../2-chimera_detection/F272/F272-nonchimeras.fasta
# F273-nc	fasta	../2-chimera_detection/F273/F273-nonchimeras.fasta
# F274-nc	fasta	../2-chimera_detection/F274/F274-nonchimeras.fasta
# F275-nc	fasta	../2-chimera_detection/F275/F275-nonchimeras.fasta
# F276-nc	fasta	../2-chimera_detection/F276/F276-nonchimeras.fasta
# F277-nc	fasta	../2-chimera_detection/F277/F277-nonchimeras.fasta
# F278-nc	fasta	../2-chimera_detection/F278/F278-nonchimeras.fasta
# F279-nc	fasta	../2-chimera_detection/F279/F279-nonchimeras.fasta
# F28-nc	fasta	../2-chimera_detection/F28/F28-nonchimeras.fasta
# F280-nc	fasta	../2-chimera_detection/F280/F280-nonchimeras.fasta
# F281-nc	fasta	../2-chimera_detection/F281/F281-nonchimeras.fasta
# F282-nc	fasta	../2-chimera_detection/F282/F282-nonchimeras.fasta
# F283-nc	fasta	../2-chimera_detection/F283/F283-nonchimeras.fasta
# F284-nc	fasta	../2-chimera_detection/F284/F284-nonchimeras.fasta
# F285-nc	fasta	../2-chimera_detection/F285/F285-nonchimeras.fasta
# F286-nc	fasta	../2-chimera_detection/F286/F286-nonchimeras.fasta
# F287-nc	fasta	../2-chimera_detection/F287/F287-nonchimeras.fasta
# F288-nc	fasta	../2-chimera_detection/F288/F288-nonchimeras.fasta
# F289-nc	fasta	../2-chimera_detection/F289/F289-nonchimeras.fasta
# F29-nc	fasta	../2-chimera_detection/F29/F29-nonchimeras.fasta
# F290-nc	fasta	../2-chimera_detection/F290/F290-nonchimeras.fasta
# F291-nc	fasta	../2-chimera_detection/F291/F291-nonchimeras.fasta
# F292-nc	fasta	../2-chimera_detection/F292/F292-nonchimeras.fasta
# F293-nc	fasta	../2-chimera_detection/F293/F293-nonchimeras.fasta
# F294-nc	fasta	../2-chimera_detection/F294/F294-nonchimeras.fasta
# F295-nc	fasta	../2-chimera_detection/F295/F295-nonchimeras.fasta
# F296-nc	fasta	../2-chimera_detection/F296/F296-nonchimeras.fasta
# F297-nc	fasta	../2-chimera_detection/F297/F297-nonchimeras.fasta
# F298-nc	fasta	../2-chimera_detection/F298/F298-nonchimeras.fasta
# F299-nc	fasta	../2-chimera_detection/F299/F299-nonchimeras.fasta
# F3-nc	fasta	../2-chimera_detection/F3/F3-nonchimeras.fasta
# F30-nc	fasta	../2-chimera_detection/F30/F30-nonchimeras.fasta
# F300-nc	fasta	../2-chimera_detection/F300/F300-nonchimeras.fasta
# F301-nc	fasta	../2-chimera_detection/F301/F301-nonchimeras.fasta
# F302-nc	fasta	../2-chimera_detection/F302/F302-nonchimeras.fasta
# F303-nc	fasta	../2-chimera_detection/F303/F303-nonchimeras.fasta
# F304-nc	fasta	../2-chimera_detection/F304/F304-nonchimeras.fasta
# F305-nc	fasta	../2-chimera_detection/F305/F305-nonchimeras.fasta
# F306-nc	fasta	../2-chimera_detection/F306/F306-nonchimeras.fasta
# F307-nc	fasta	../2-chimera_detection/F307/F307-nonchimeras.fasta
# F308-nc	fasta	../2-chimera_detection/F308/F308-nonchimeras.fasta
# F309-nc	fasta	../2-chimera_detection/F309/F309-nonchimeras.fasta
# F31-nc	fasta	../2-chimera_detection/F31/F31-nonchimeras.fasta
# F310-nc	fasta	../2-chimera_detection/F310/F310-nonchimeras.fasta
# F311-nc	fasta	../2-chimera_detection/F311/F311-nonchimeras.fasta
# F312-nc	fasta	../2-chimera_detection/F312/F312-nonchimeras.fasta
# F313-nc	fasta	../2-chimera_detection/F313/F313-nonchimeras.fasta
# F314-nc	fasta	../2-chimera_detection/F314/F314-nonchimeras.fasta
# F315-nc	fasta	../2-chimera_detection/F315/F315-nonchimeras.fasta
# F316-nc	fasta	../2-chimera_detection/F316/F316-nonchimeras.fasta
# F317-nc	fasta	../2-chimera_detection/F317/F317-nonchimeras.fasta
# F318-nc	fasta	../2-chimera_detection/F318/F318-nonchimeras.fasta
# F319-nc	fasta	../2-chimera_detection/F319/F319-nonchimeras.fasta
# F32-nc	fasta	../2-chimera_detection/F32/F32-nonchimeras.fasta
# F320-nc	fasta	../2-chimera_detection/F320/F320-nonchimeras.fasta
# F321-nc	fasta	../2-chimera_detection/F321/F321-nonchimeras.fasta
# F322-nc	fasta	../2-chimera_detection/F322/F322-nonchimeras.fasta
# F323-nc	fasta	../2-chimera_detection/F323/F323-nonchimeras.fasta
# F324-nc	fasta	../2-chimera_detection/F324/F324-nonchimeras.fasta
# F325-nc	fasta	../2-chimera_detection/F325/F325-nonchimeras.fasta
# F326-nc	fasta	../2-chimera_detection/F326/F326-nonchimeras.fasta
# F327-nc	fasta	../2-chimera_detection/F327/F327-nonchimeras.fasta
# F328-nc	fasta	../2-chimera_detection/F328/F328-nonchimeras.fasta
# F329-nc	fasta	../2-chimera_detection/F329/F329-nonchimeras.fasta
# F33-nc	fasta	../2-chimera_detection/F33/F33-nonchimeras.fasta
# F330-nc	fasta	../2-chimera_detection/F330/F330-nonchimeras.fasta
# F331-nc	fasta	../2-chimera_detection/F331/F331-nonchimeras.fasta
# F332-nc	fasta	../2-chimera_detection/F332/F332-nonchimeras.fasta
# F333-nc	fasta	../2-chimera_detection/F333/F333-nonchimeras.fasta
# F334-nc	fasta	../2-chimera_detection/F334/F334-nonchimeras.fasta
# F335-nc	fasta	../2-chimera_detection/F335/F335-nonchimeras.fasta
# F336-nc	fasta	../2-chimera_detection/F336/F336-nonchimeras.fasta
# F337-nc	fasta	../2-chimera_detection/F337/F337-nonchimeras.fasta
# F338-nc	fasta	../2-chimera_detection/F338/F338-nonchimeras.fasta
# F339-nc	fasta	../2-chimera_detection/F339/F339-nonchimeras.fasta
# F34-nc	fasta	../2-chimera_detection/F34/F34-nonchimeras.fasta
# F340-nc	fasta	../2-chimera_detection/F340/F340-nonchimeras.fasta
# F341-nc	fasta	../2-chimera_detection/F341/F341-nonchimeras.fasta
# F342-nc	fasta	../2-chimera_detection/F342/F342-nonchimeras.fasta
# F343-nc	fasta	../2-chimera_detection/F343/F343-nonchimeras.fasta
# F344-nc	fasta	../2-chimera_detection/F344/F344-nonchimeras.fasta
# F345-nc	fasta	../2-chimera_detection/F345/F345-nonchimeras.fasta
# F346-nc	fasta	../2-chimera_detection/F346/F346-nonchimeras.fasta
# F347-nc	fasta	../2-chimera_detection/F347/F347-nonchimeras.fasta
# F348-nc	fasta	../2-chimera_detection/F348/F348-nonchimeras.fasta
# F349-nc	fasta	../2-chimera_detection/F349/F349-nonchimeras.fasta
# F35-nc	fasta	../2-chimera_detection/F35/F35-nonchimeras.fasta
# F350-nc	fasta	../2-chimera_detection/F350/F350-nonchimeras.fasta
# F351-nc	fasta	../2-chimera_detection/F351/F351-nonchimeras.fasta
# F352-nc	fasta	../2-chimera_detection/F352/F352-nonchimeras.fasta
# F353-nc	fasta	../2-chimera_detection/F353/F353-nonchimeras.fasta
# F354-nc	fasta	../2-chimera_detection/F354/F354-nonchimeras.fasta
# F355-nc	fasta	../2-chimera_detection/F355/F355-nonchimeras.fasta
# F356-nc	fasta	../2-chimera_detection/F356/F356-nonchimeras.fasta
# F357-nc	fasta	../2-chimera_detection/F357/F357-nonchimeras.fasta
# F358-nc	fasta	../2-chimera_detection/F358/F358-nonchimeras.fasta
# F359-nc	fasta	../2-chimera_detection/F359/F359-nonchimeras.fasta
# F36-nc	fasta	../2-chimera_detection/F36/F36-nonchimeras.fasta
# F360-nc	fasta	../2-chimera_detection/F360/F360-nonchimeras.fasta
# F361-nc	fasta	../2-chimera_detection/F361/F361-nonchimeras.fasta
# F362-nc	fasta	../2-chimera_detection/F362/F362-nonchimeras.fasta
# F363-nc	fasta	../2-chimera_detection/F363/F363-nonchimeras.fasta
# F364-nc	fasta	../2-chimera_detection/F364/F364-nonchimeras.fasta
# F365-nc	fasta	../2-chimera_detection/F365/F365-nonchimeras.fasta
# F366-nc	fasta	../2-chimera_detection/F366/F366-nonchimeras.fasta
# F367-nc	fasta	../2-chimera_detection/F367/F367-nonchimeras.fasta
# F368-nc	fasta	../2-chimera_detection/F368/F368-nonchimeras.fasta
# F369-nc	fasta	../2-chimera_detection/F369/F369-nonchimeras.fasta
# F37-nc	fasta	../2-chimera_detection/F37/F37-nonchimeras.fasta
# F370-nc	fasta	../2-chimera_detection/F370/F370-nonchimeras.fasta
# F371-nc	fasta	../2-chimera_detection/F371/F371-nonchimeras.fasta
# F372-nc	fasta	../2-chimera_detection/F372/F372-nonchimeras.fasta
# F373-nc	fasta	../2-chimera_detection/F373/F373-nonchimeras.fasta
# F374-nc	fasta	../2-chimera_detection/F374/F374-nonchimeras.fasta
# F375-nc	fasta	../2-chimera_detection/F375/F375-nonchimeras.fasta
# F376-nc	fasta	../2-chimera_detection/F376/F376-nonchimeras.fasta
# F377-nc	fasta	../2-chimera_detection/F377/F377-nonchimeras.fasta
# F378-nc	fasta	../2-chimera_detection/F378/F378-nonchimeras.fasta
# F379-nc	fasta	../2-chimera_detection/F379/F379-nonchimeras.fasta
# F38-nc	fasta	../2-chimera_detection/F38/F38-nonchimeras.fasta
# F380-nc	fasta	../2-chimera_detection/F380/F380-nonchimeras.fasta
# F381-nc	fasta	../2-chimera_detection/F381/F381-nonchimeras.fasta
# F382-nc	fasta	../2-chimera_detection/F382/F382-nonchimeras.fasta
# F383-nc	fasta	../2-chimera_detection/F383/F383-nonchimeras.fasta
# F384-nc	fasta	../2-chimera_detection/F384/F384-nonchimeras.fasta
# F385-nc	fasta	../2-chimera_detection/F385/F385-nonchimeras.fasta
# F386-nc	fasta	../2-chimera_detection/F386/F386-nonchimeras.fasta
# F387-nc	fasta	../2-chimera_detection/F387/F387-nonchimeras.fasta
# F388-nc	fasta	../2-chimera_detection/F388/F388-nonchimeras.fasta
# F389-nc	fasta	../2-chimera_detection/F389/F389-nonchimeras.fasta
# F39-nc	fasta	../2-chimera_detection/F39/F39-nonchimeras.fasta
# F390-nc	fasta	../2-chimera_detection/F390/F390-nonchimeras.fasta
# F391-nc	fasta	../2-chimera_detection/F391/F391-nonchimeras.fasta
# F392-nc	fasta	../2-chimera_detection/F392/F392-nonchimeras.fasta
# F393-nc	fasta	../2-chimera_detection/F393/F393-nonchimeras.fasta
# F394-nc	fasta	../2-chimera_detection/F394/F394-nonchimeras.fasta
# F395-nc	fasta	../2-chimera_detection/F395/F395-nonchimeras.fasta
# F396-nc	fasta	../2-chimera_detection/F396/F396-nonchimeras.fasta
# F397-nc	fasta	../2-chimera_detection/F397/F397-nonchimeras.fasta
# F398-nc	fasta	../2-chimera_detection/F398/F398-nonchimeras.fasta
# F399-nc	fasta	../2-chimera_detection/F399/F399-nonchimeras.fasta
# F4-nc	fasta	../2-chimera_detection/F4/F4-nonchimeras.fasta
# F40-nc	fasta	../2-chimera_detection/F40/F40-nonchimeras.fasta
# F400-nc	fasta	../2-chimera_detection/F400/F400-nonchimeras.fasta
# F401-nc	fasta	../2-chimera_detection/F401/F401-nonchimeras.fasta
# F402-nc	fasta	../2-chimera_detection/F402/F402-nonchimeras.fasta
# F403-nc	fasta	../2-chimera_detection/F403/F403-nonchimeras.fasta
# F404-nc	fasta	../2-chimera_detection/F404/F404-nonchimeras.fasta
# F405-nc	fasta	../2-chimera_detection/F405/F405-nonchimeras.fasta
# F406-nc	fasta	../2-chimera_detection/F406/F406-nonchimeras.fasta
# F407-nc	fasta	../2-chimera_detection/F407/F407-nonchimeras.fasta
# F408-nc	fasta	../2-chimera_detection/F408/F408-nonchimeras.fasta
# F409-nc	fasta	../2-chimera_detection/F409/F409-nonchimeras.fasta
# F41-nc	fasta	../2-chimera_detection/F41/F41-nonchimeras.fasta
# F410-nc	fasta	../2-chimera_detection/F410/F410-nonchimeras.fasta
# F411-nc	fasta	../2-chimera_detection/F411/F411-nonchimeras.fasta
# F412-nc	fasta	../2-chimera_detection/F412/F412-nonchimeras.fasta
# F413-nc	fasta	../2-chimera_detection/F413/F413-nonchimeras.fasta
# F414-nc	fasta	../2-chimera_detection/F414/F414-nonchimeras.fasta
# F415-nc	fasta	../2-chimera_detection/F415/F415-nonchimeras.fasta
# F416-nc	fasta	../2-chimera_detection/F416/F416-nonchimeras.fasta
# F417-nc	fasta	../2-chimera_detection/F417/F417-nonchimeras.fasta
# F418-nc	fasta	../2-chimera_detection/F418/F418-nonchimeras.fasta
# F419-nc	fasta	../2-chimera_detection/F419/F419-nonchimeras.fasta
# F42-nc	fasta	../2-chimera_detection/F42/F42-nonchimeras.fasta
# F420-nc	fasta	../2-chimera_detection/F420/F420-nonchimeras.fasta
# F421-nc	fasta	../2-chimera_detection/F421/F421-nonchimeras.fasta
# F422-nc	fasta	../2-chimera_detection/F422/F422-nonchimeras.fasta
# F423-nc	fasta	../2-chimera_detection/F423/F423-nonchimeras.fasta
# F424-nc	fasta	../2-chimera_detection/F424/F424-nonchimeras.fasta
# F425-nc	fasta	../2-chimera_detection/F425/F425-nonchimeras.fasta
# F426-nc	fasta	../2-chimera_detection/F426/F426-nonchimeras.fasta
# F427-nc	fasta	../2-chimera_detection/F427/F427-nonchimeras.fasta
# F428-nc	fasta	../2-chimera_detection/F428/F428-nonchimeras.fasta
# F429-nc	fasta	../2-chimera_detection/F429/F429-nonchimeras.fasta
# F43-nc	fasta	../2-chimera_detection/F43/F43-nonchimeras.fasta
# F430-nc	fasta	../2-chimera_detection/F430/F430-nonchimeras.fasta
# F431-nc	fasta	../2-chimera_detection/F431/F431-nonchimeras.fasta
# F432-nc	fasta	../2-chimera_detection/F432/F432-nonchimeras.fasta
# F433-nc	fasta	../2-chimera_detection/F433/F433-nonchimeras.fasta
# F434-nc	fasta	../2-chimera_detection/F434/F434-nonchimeras.fasta
# F435-nc	fasta	../2-chimera_detection/F435/F435-nonchimeras.fasta
# F436-nc	fasta	../2-chimera_detection/F436/F436-nonchimeras.fasta
# F437-nc	fasta	../2-chimera_detection/F437/F437-nonchimeras.fasta
# F438-nc	fasta	../2-chimera_detection/F438/F438-nonchimeras.fasta
# F439-nc	fasta	../2-chimera_detection/F439/F439-nonchimeras.fasta
# F44-nc	fasta	../2-chimera_detection/F44/F44-nonchimeras.fasta
# F440-nc	fasta	../2-chimera_detection/F440/F440-nonchimeras.fasta
# F441-nc	fasta	../2-chimera_detection/F441/F441-nonchimeras.fasta
# F442-nc	fasta	../2-chimera_detection/F442/F442-nonchimeras.fasta
# F443-nc	fasta	../2-chimera_detection/F443/F443-nonchimeras.fasta
# F444-nc	fasta	../2-chimera_detection/F444/F444-nonchimeras.fasta
# F445-nc	fasta	../2-chimera_detection/F445/F445-nonchimeras.fasta
# F446-nc	fasta	../2-chimera_detection/F446/F446-nonchimeras.fasta
# F447-nc	fasta	../2-chimera_detection/F447/F447-nonchimeras.fasta
# F448-nc	fasta	../2-chimera_detection/F448/F448-nonchimeras.fasta
# F449-nc	fasta	../2-chimera_detection/F449/F449-nonchimeras.fasta
# F45-nc	fasta	../2-chimera_detection/F45/F45-nonchimeras.fasta
# F450-nc	fasta	../2-chimera_detection/F450/F450-nonchimeras.fasta
# F451-nc	fasta	../2-chimera_detection/F451/F451-nonchimeras.fasta
# F452-nc	fasta	../2-chimera_detection/F452/F452-nonchimeras.fasta
# F453-nc	fasta	../2-chimera_detection/F453/F453-nonchimeras.fasta
# F454-nc	fasta	../2-chimera_detection/F454/F454-nonchimeras.fasta
# F455-nc	fasta	../2-chimera_detection/F455/F455-nonchimeras.fasta
# F456-nc	fasta	../2-chimera_detection/F456/F456-nonchimeras.fasta
# F457-nc	fasta	../2-chimera_detection/F457/F457-nonchimeras.fasta
# F458-nc	fasta	../2-chimera_detection/F458/F458-nonchimeras.fasta
# F459-nc	fasta	../2-chimera_detection/F459/F459-nonchimeras.fasta
# F46-nc	fasta	../2-chimera_detection/F46/F46-nonchimeras.fasta
# F460-nc	fasta	../2-chimera_detection/F460/F460-nonchimeras.fasta
# F461-nc	fasta	../2-chimera_detection/F461/F461-nonchimeras.fasta
# F462-nc	fasta	../2-chimera_detection/F462/F462-nonchimeras.fasta
# F463-nc	fasta	../2-chimera_detection/F463/F463-nonchimeras.fasta
# F464-nc	fasta	../2-chimera_detection/F464/F464-nonchimeras.fasta
# F465-nc	fasta	../2-chimera_detection/F465/F465-nonchimeras.fasta
# F466-nc	fasta	../2-chimera_detection/F466/F466-nonchimeras.fasta
# F467-nc	fasta	../2-chimera_detection/F467/F467-nonchimeras.fasta
# F468-nc	fasta	../2-chimera_detection/F468/F468-nonchimeras.fasta
# F469-nc	fasta	../2-chimera_detection/F469/F469-nonchimeras.fasta
# F47-nc	fasta	../2-chimera_detection/F47/F47-nonchimeras.fasta
# F470-nc	fasta	../2-chimera_detection/F470/F470-nonchimeras.fasta
# F471-nc	fasta	../2-chimera_detection/F471/F471-nonchimeras.fasta
# F472-nc	fasta	../2-chimera_detection/F472/F472-nonchimeras.fasta
# F473-nc	fasta	../2-chimera_detection/F473/F473-nonchimeras.fasta
# F474-nc	fasta	../2-chimera_detection/F474/F474-nonchimeras.fasta
# F475-nc	fasta	../2-chimera_detection/F475/F475-nonchimeras.fasta
# F476-nc	fasta	../2-chimera_detection/F476/F476-nonchimeras.fasta
# F477-nc	fasta	../2-chimera_detection/F477/F477-nonchimeras.fasta
# F478-nc	fasta	../2-chimera_detection/F478/F478-nonchimeras.fasta
# F479-nc	fasta	../2-chimera_detection/F479/F479-nonchimeras.fasta
# F48-nc	fasta	../2-chimera_detection/F48/F48-nonchimeras.fasta
# F480-nc	fasta	../2-chimera_detection/F480/F480-nonchimeras.fasta
# F481-nc	fasta	../2-chimera_detection/F481/F481-nonchimeras.fasta
# F482-nc	fasta	../2-chimera_detection/F482/F482-nonchimeras.fasta
# F483-nc	fasta	../2-chimera_detection/F483/F483-nonchimeras.fasta
# F484-nc	fasta	../2-chimera_detection/F484/F484-nonchimeras.fasta
# F485-nc	fasta	../2-chimera_detection/F485/F485-nonchimeras.fasta
# F486-nc	fasta	../2-chimera_detection/F486/F486-nonchimeras.fasta
# F487-nc	fasta	../2-chimera_detection/F487/F487-nonchimeras.fasta
# F488-nc	fasta	../2-chimera_detection/F488/F488-nonchimeras.fasta
# F489-nc	fasta	../2-chimera_detection/F489/F489-nonchimeras.fasta
# F49-nc	fasta	../2-chimera_detection/F49/F49-nonchimeras.fasta
# F490-nc	fasta	../2-chimera_detection/F490/F490-nonchimeras.fasta
# F491-nc	fasta	../2-chimera_detection/F491/F491-nonchimeras.fasta
# F492-nc	fasta	../2-chimera_detection/F492/F492-nonchimeras.fasta
# F493-nc	fasta	../2-chimera_detection/F493/F493-nonchimeras.fasta
# F494-nc	fasta	../2-chimera_detection/F494/F494-nonchimeras.fasta
# F495-nc	fasta	../2-chimera_detection/F495/F495-nonchimeras.fasta
# F496-nc	fasta	../2-chimera_detection/F496/F496-nonchimeras.fasta
# F497-nc	fasta	../2-chimera_detection/F497/F497-nonchimeras.fasta
# F498-nc	fasta	../2-chimera_detection/F498/F498-nonchimeras.fasta
# F499-nc	fasta	../2-chimera_detection/F499/F499-nonchimeras.fasta
# F5-nc	fasta	../2-chimera_detection/F5/F5-nonchimeras.fasta
# F50-nc	fasta	../2-chimera_detection/F50/F50-nonchimeras.fasta
# F500-nc	fasta	../2-chimera_detection/F500/F500-nonchimeras.fasta
# F501-nc	fasta	../2-chimera_detection/F501/F501-nonchimeras.fasta
# F502-nc	fasta	../2-chimera_detection/F502/F502-nonchimeras.fasta
# F503-nc	fasta	../2-chimera_detection/F503/F503-nonchimeras.fasta
# F504-nc	fasta	../2-chimera_detection/F504/F504-nonchimeras.fasta
# F505-nc	fasta	../2-chimera_detection/F505/F505-nonchimeras.fasta
# F506-nc	fasta	../2-chimera_detection/F506/F506-nonchimeras.fasta
# F507-nc	fasta	../2-chimera_detection/F507/F507-nonchimeras.fasta
# F508-nc	fasta	../2-chimera_detection/F508/F508-nonchimeras.fasta
# F51-nc	fasta	../2-chimera_detection/F51/F51-nonchimeras.fasta
# F52-nc	fasta	../2-chimera_detection/F52/F52-nonchimeras.fasta
# F53-nc	fasta	../2-chimera_detection/F53/F53-nonchimeras.fasta
# F54-nc	fasta	../2-chimera_detection/F54/F54-nonchimeras.fasta
# F55-nc	fasta	../2-chimera_detection/F55/F55-nonchimeras.fasta
# F56-nc	fasta	../2-chimera_detection/F56/F56-nonchimeras.fasta
# F57-nc	fasta	../2-chimera_detection/F57/F57-nonchimeras.fasta
# F58-nc	fasta	../2-chimera_detection/F58/F58-nonchimeras.fasta
# F59-nc	fasta	../2-chimera_detection/F59/F59-nonchimeras.fasta
# F6-nc	fasta	../2-chimera_detection/F6/F6-nonchimeras.fasta
# F60-nc	fasta	../2-chimera_detection/F60/F60-nonchimeras.fasta
# F61-nc	fasta	../2-chimera_detection/F61/F61-nonchimeras.fasta
# F62-nc	fasta	../2-chimera_detection/F62/F62-nonchimeras.fasta
# F63-nc	fasta	../2-chimera_detection/F63/F63-nonchimeras.fasta
# F64-nc	fasta	../2-chimera_detection/F64/F64-nonchimeras.fasta
# F65-nc	fasta	../2-chimera_detection/F65/F65-nonchimeras.fasta
# F66-nc	fasta	../2-chimera_detection/F66/F66-nonchimeras.fasta
# F67-nc	fasta	../2-chimera_detection/F67/F67-nonchimeras.fasta
# F68-nc	fasta	../2-chimera_detection/F68/F68-nonchimeras.fasta
# F69-nc	fasta	../2-chimera_detection/F69/F69-nonchimeras.fasta
# F7-nc	fasta	../2-chimera_detection/F7/F7-nonchimeras.fasta
# F70-nc	fasta	../2-chimera_detection/F70/F70-nonchimeras.fasta
# F71-nc	fasta	../2-chimera_detection/F71/F71-nonchimeras.fasta
# F72-nc	fasta	../2-chimera_detection/F72/F72-nonchimeras.fasta
# F73-nc	fasta	../2-chimera_detection/F73/F73-nonchimeras.fasta
# F74-nc	fasta	../2-chimera_detection/F74/F74-nonchimeras.fasta
# F75-nc	fasta	../2-chimera_detection/F75/F75-nonchimeras.fasta
# F76-nc	fasta	../2-chimera_detection/F76/F76-nonchimeras.fasta
# F77-nc	fasta	../2-chimera_detection/F77/F77-nonchimeras.fasta
# F78-nc	fasta	../2-chimera_detection/F78/F78-nonchimeras.fasta
# F79-nc	fasta	../2-chimera_detection/F79/F79-nonchimeras.fasta
# F8-nc	fasta	../2-chimera_detection/F8/F8-nonchimeras.fasta
# F80-nc	fasta	../2-chimera_detection/F80/F80-nonchimeras.fasta
# F81-nc	fasta	../2-chimera_detection/F81/F81-nonchimeras.fasta
# F82-nc	fasta	../2-chimera_detection/F82/F82-nonchimeras.fasta
# F83-nc	fasta	../2-chimera_detection/F83/F83-nonchimeras.fasta
# F84-nc	fasta	../2-chimera_detection/F84/F84-nonchimeras.fasta
# F85-nc	fasta	../2-chimera_detection/F85/F85-nonchimeras.fasta
# F86-nc	fasta	../2-chimera_detection/F86/F86-nonchimeras.fasta
# F87-nc	fasta	../2-chimera_detection/F87/F87-nonchimeras.fasta
# F88-nc	fasta	../2-chimera_detection/F88/F88-nonchimeras.fasta
# F89-nc	fasta	../2-chimera_detection/F89/F89-nonchimeras.fasta
# F9-nc	fasta	../2-chimera_detection/F9/F9-nonchimeras.fasta
# F90-nc	fasta	../2-chimera_detection/F90/F90-nonchimeras.fasta
# F91-nc	fasta	../2-chimera_detection/F91/F91-nonchimeras.fasta
# F92-nc	fasta	../2-chimera_detection/F92/F92-nonchimeras.fasta
# F93-nc	fasta	../2-chimera_detection/F93/F93-nonchimeras.fasta
# F94-nc	fasta	../2-chimera_detection/F94/F94-nonchimeras.fasta
# F95-nc	fasta	../2-chimera_detection/F95/F95-nonchimeras.fasta
# F96-nc	fasta	../2-chimera_detection/F96/F96-nonchimeras.fasta
# F97-nc	fasta	../2-chimera_detection/F97/F97-nonchimeras.fasta
# F98-nc	fasta	../2-chimera_detection/F98/F98-nonchimeras.fasta
# F99-nc	fasta	../2-chimera_detection/F99/F99-nonchimeras.fasta
# N10-1-nc	fasta	../2-chimera_detection/N10-1/N10-1-nonchimeras.fasta
# N10-2-nc	fasta	../2-chimera_detection/N10-2/N10-2-nonchimeras.fasta
# N10-3-nc	fasta	../2-chimera_detection/N10-3/N10-3-nonchimeras.fasta
# N10-4-nc	fasta	../2-chimera_detection/N10-4/N10-4-nonchimeras.fasta
# N10-5-nc	fasta	../2-chimera_detection/N10-5/N10-5-nonchimeras.fasta
# N10-6-nc	fasta	../2-chimera_detection/N10-6/N10-6-nonchimeras.fasta
# N1-1-nc	fasta	../2-chimera_detection/N1-1/N1-1-nonchimeras.fasta
# N11-1-nc	fasta	../2-chimera_detection/N11-1/N11-1-nonchimeras.fasta
# N11-2-nc	fasta	../2-chimera_detection/N11-2/N11-2-nonchimeras.fasta
# N11-3-nc	fasta	../2-chimera_detection/N11-3/N11-3-nonchimeras.fasta
# N11-4-nc	fasta	../2-chimera_detection/N11-4/N11-4-nonchimeras.fasta
# N11-5-nc	fasta	../2-chimera_detection/N11-5/N11-5-nonchimeras.fasta
# N11-6-nc	fasta	../2-chimera_detection/N11-6/N11-6-nonchimeras.fasta
# N1-2-nc	fasta	../2-chimera_detection/N1-2/N1-2-nonchimeras.fasta
# N12-1-nc	fasta	../2-chimera_detection/N12-1/N12-1-nonchimeras.fasta
# N12-2-nc	fasta	../2-chimera_detection/N12-2/N12-2-nonchimeras.fasta
# N12-3-nc	fasta	../2-chimera_detection/N12-3/N12-3-nonchimeras.fasta
# N12-4-nc	fasta	../2-chimera_detection/N12-4/N12-4-nonchimeras.fasta
# N12-5-nc	fasta	../2-chimera_detection/N12-5/N12-5-nonchimeras.fasta
# N12-6-nc	fasta	../2-chimera_detection/N12-6/N12-6-nonchimeras.fasta
# N1-3-nc	fasta	../2-chimera_detection/N1-3/N1-3-nonchimeras.fasta
# N13-1-nc	fasta	../2-chimera_detection/N13-1/N13-1-nonchimeras.fasta
# N13-2-nc	fasta	../2-chimera_detection/N13-2/N13-2-nonchimeras.fasta
# N13-3-nc	fasta	../2-chimera_detection/N13-3/N13-3-nonchimeras.fasta
# N13-4-nc	fasta	../2-chimera_detection/N13-4/N13-4-nonchimeras.fasta
# N13-5-nc	fasta	../2-chimera_detection/N13-5/N13-5-nonchimeras.fasta
# N13-6-nc	fasta	../2-chimera_detection/N13-6/N13-6-nonchimeras.fasta
# N1-4-nc	fasta	../2-chimera_detection/N1-4/N1-4-nonchimeras.fasta
# N14-1-nc	fasta	../2-chimera_detection/N14-1/N14-1-nonchimeras.fasta
# N14-2-nc	fasta	../2-chimera_detection/N14-2/N14-2-nonchimeras.fasta
# N14-3-nc	fasta	../2-chimera_detection/N14-3/N14-3-nonchimeras.fasta
# N14-4-nc	fasta	../2-chimera_detection/N14-4/N14-4-nonchimeras.fasta
# N14-5-nc	fasta	../2-chimera_detection/N14-5/N14-5-nonchimeras.fasta
# N14-6-nc	fasta	../2-chimera_detection/N14-6/N14-6-nonchimeras.fasta
# N1-5-nc	fasta	../2-chimera_detection/N1-5/N1-5-nonchimeras.fasta
# N15-1-nc	fasta	../2-chimera_detection/N15-1/N15-1-nonchimeras.fasta
# N15-2-nc	fasta	../2-chimera_detection/N15-2/N15-2-nonchimeras.fasta
# N15-3-nc	fasta	../2-chimera_detection/N15-3/N15-3-nonchimeras.fasta
# N15-4-nc	fasta	../2-chimera_detection/N15-4/N15-4-nonchimeras.fasta
# N15-5-nc	fasta	../2-chimera_detection/N15-5/N15-5-nonchimeras.fasta
# N15-6-nc	fasta	../2-chimera_detection/N15-6/N15-6-nonchimeras.fasta
# N1-6-nc	fasta	../2-chimera_detection/N1-6/N1-6-nonchimeras.fasta
# N16-1-nc	fasta	../2-chimera_detection/N16-1/N16-1-nonchimeras.fasta
# N16-2-nc	fasta	../2-chimera_detection/N16-2/N16-2-nonchimeras.fasta
# N16-3-nc	fasta	../2-chimera_detection/N16-3/N16-3-nonchimeras.fasta
# N16-4-nc	fasta	../2-chimera_detection/N16-4/N16-4-nonchimeras.fasta
# N16-5-nc	fasta	../2-chimera_detection/N16-5/N16-5-nonchimeras.fasta
# N16-6-nc	fasta	../2-chimera_detection/N16-6/N16-6-nonchimeras.fasta
# N17-1-nc	fasta	../2-chimera_detection/N17-1/N17-1-nonchimeras.fasta
# N17-2-nc	fasta	../2-chimera_detection/N17-2/N17-2-nonchimeras.fasta
# N17-3-nc	fasta	../2-chimera_detection/N17-3/N17-3-nonchimeras.fasta
# N17-4-nc	fasta	../2-chimera_detection/N17-4/N17-4-nonchimeras.fasta
# N17-5-nc	fasta	../2-chimera_detection/N17-5/N17-5-nonchimeras.fasta
# N17-6-nc	fasta	../2-chimera_detection/N17-6/N17-6-nonchimeras.fasta
# N18-1-nc	fasta	../2-chimera_detection/N18-1/N18-1-nonchimeras.fasta
# N18-2-nc	fasta	../2-chimera_detection/N18-2/N18-2-nonchimeras.fasta
# N18-3-nc	fasta	../2-chimera_detection/N18-3/N18-3-nonchimeras.fasta
# N18-4-nc	fasta	../2-chimera_detection/N18-4/N18-4-nonchimeras.fasta
# N18-5-nc	fasta	../2-chimera_detection/N18-5/N18-5-nonchimeras.fasta
# N18-6-nc	fasta	../2-chimera_detection/N18-6/N18-6-nonchimeras.fasta
# N19-1-nc	fasta	../2-chimera_detection/N19-1/N19-1-nonchimeras.fasta
# N19-2-nc	fasta	../2-chimera_detection/N19-2/N19-2-nonchimeras.fasta
# N19-3-nc	fasta	../2-chimera_detection/N19-3/N19-3-nonchimeras.fasta
# N19-4-nc	fasta	../2-chimera_detection/N19-4/N19-4-nonchimeras.fasta
# N19-5-nc	fasta	../2-chimera_detection/N19-5/N19-5-nonchimeras.fasta
# N19-6-nc	fasta	../2-chimera_detection/N19-6/N19-6-nonchimeras.fasta
# N2-1-nc	fasta	../2-chimera_detection/N2-1/N2-1-nonchimeras.fasta
# N2-2-nc	fasta	../2-chimera_detection/N2-2/N2-2-nonchimeras.fasta
# N2-3-nc	fasta	../2-chimera_detection/N2-3/N2-3-nonchimeras.fasta
# N2-4-nc	fasta	../2-chimera_detection/N2-4/N2-4-nonchimeras.fasta
# N2-5-nc	fasta	../2-chimera_detection/N2-5/N2-5-nonchimeras.fasta
# N2-6-nc	fasta	../2-chimera_detection/N2-6/N2-6-nonchimeras.fasta
# N3-1-nc	fasta	../2-chimera_detection/N3-1/N3-1-nonchimeras.fasta
# N3-2-nc	fasta	../2-chimera_detection/N3-2/N3-2-nonchimeras.fasta
# N3-3-nc	fasta	../2-chimera_detection/N3-3/N3-3-nonchimeras.fasta
# N3-4-nc	fasta	../2-chimera_detection/N3-4/N3-4-nonchimeras.fasta
# N3-5-nc	fasta	../2-chimera_detection/N3-5/N3-5-nonchimeras.fasta
# N3-6-nc	fasta	../2-chimera_detection/N3-6/N3-6-nonchimeras.fasta
# N4-1-nc	fasta	../2-chimera_detection/N4-1/N4-1-nonchimeras.fasta
# N4-2-nc	fasta	../2-chimera_detection/N4-2/N4-2-nonchimeras.fasta
# N4-3-nc	fasta	../2-chimera_detection/N4-3/N4-3-nonchimeras.fasta
# N4-4-nc	fasta	../2-chimera_detection/N4-4/N4-4-nonchimeras.fasta
# N4-5-nc	fasta	../2-chimera_detection/N4-5/N4-5-nonchimeras.fasta
# N4-6-nc	fasta	../2-chimera_detection/N4-6/N4-6-nonchimeras.fasta
# N5-1-nc	fasta	../2-chimera_detection/N5-1/N5-1-nonchimeras.fasta
# N5-2-nc	fasta	../2-chimera_detection/N5-2/N5-2-nonchimeras.fasta
# N5-3-nc	fasta	../2-chimera_detection/N5-3/N5-3-nonchimeras.fasta
# N5-4-nc	fasta	../2-chimera_detection/N5-4/N5-4-nonchimeras.fasta
# N5-5-nc	fasta	../2-chimera_detection/N5-5/N5-5-nonchimeras.fasta
# N5-6-nc	fasta	../2-chimera_detection/N5-6/N5-6-nonchimeras.fasta
# N6-1-nc	fasta	../2-chimera_detection/N6-1/N6-1-nonchimeras.fasta
# N6-2-nc	fasta	../2-chimera_detection/N6-2/N6-2-nonchimeras.fasta
# N6-3-nc	fasta	../2-chimera_detection/N6-3/N6-3-nonchimeras.fasta
# N6-4-nc	fasta	../2-chimera_detection/N6-4/N6-4-nonchimeras.fasta
# N6-5-nc	fasta	../2-chimera_detection/N6-5/N6-5-nonchimeras.fasta
# N6-6-nc	fasta	../2-chimera_detection/N6-6/N6-6-nonchimeras.fasta
# N7-1-nc	fasta	../2-chimera_detection/N7-1/N7-1-nonchimeras.fasta
# N7-2-nc	fasta	../2-chimera_detection/N7-2/N7-2-nonchimeras.fasta
# N7-3-nc	fasta	../2-chimera_detection/N7-3/N7-3-nonchimeras.fasta
# N7-4-nc	fasta	../2-chimera_detection/N7-4/N7-4-nonchimeras.fasta
# N7-5-nc	fasta	../2-chimera_detection/N7-5/N7-5-nonchimeras.fasta
# N7-6-nc	fasta	../2-chimera_detection/N7-6/N7-6-nonchimeras.fasta
# N8-1-nc	fasta	../2-chimera_detection/N8-1/N8-1-nonchimeras.fasta
# N8-2-nc	fasta	../2-chimera_detection/N8-2/N8-2-nonchimeras.fasta
# N8-3-nc	fasta	../2-chimera_detection/N8-3/N8-3-nonchimeras.fasta
# N8-4-nc	fasta	../2-chimera_detection/N8-4/N8-4-nonchimeras.fasta
# N8-5-nc	fasta	../2-chimera_detection/N8-5/N8-5-nonchimeras.fasta
# N8-6-nc	fasta	../2-chimera_detection/N8-6/N8-6-nonchimeras.fasta
# N9-1-nc	fasta	../2-chimera_detection/N9-1/N9-1-nonchimeras.fasta
# N9-2-nc	fasta	../2-chimera_detection/N9-2/N9-2-nonchimeras.fasta
# N9-3-nc	fasta	../2-chimera_detection/N9-3/N9-3-nonchimeras.fasta
# N9-4-nc	fasta	../2-chimera_detection/N9-4/N9-4-nonchimeras.fasta
# N9-5-nc	fasta	../2-chimera_detection/N9-5/N9-5-nonchimeras.fasta
# N9-6-nc	fasta	../2-chimera_detection/N9-6/N9-6-nonchimeras.fasta
# NU1-nc	fasta	../2-chimera_detection/NU1/NU1-nonchimeras.fasta
# NU10-nc	fasta	../2-chimera_detection/NU10/NU10-nonchimeras.fasta
# NU11-nc	fasta	../2-chimera_detection/NU11/NU11-nonchimeras.fasta
# NU12-nc	fasta	../2-chimera_detection/NU12/NU12-nonchimeras.fasta
# NU13-nc	fasta	../2-chimera_detection/NU13/NU13-nonchimeras.fasta
# NU14-nc	fasta	../2-chimera_detection/NU14/NU14-nonchimeras.fasta
# NU15-nc	fasta	../2-chimera_detection/NU15/NU15-nonchimeras.fasta
# NU16-nc	fasta	../2-chimera_detection/NU16/NU16-nonchimeras.fasta
# NU17-nc	fasta	../2-chimera_detection/NU17/NU17-nonchimeras.fasta
# NU18-nc	fasta	../2-chimera_detection/NU18/NU18-nonchimeras.fasta
# NU19-nc	fasta	../2-chimera_detection/NU19/NU19-nonchimeras.fasta
# NU2-nc	fasta	../2-chimera_detection/NU2/NU2-nonchimeras.fasta
# NU20-nc	fasta	../2-chimera_detection/NU20/NU20-nonchimeras.fasta
# NU21-nc	fasta	../2-chimera_detection/NU21/NU21-nonchimeras.fasta
# NU22-nc	fasta	../2-chimera_detection/NU22/NU22-nonchimeras.fasta
# NU23-nc	fasta	../2-chimera_detection/NU23/NU23-nonchimeras.fasta
# NU24-nc	fasta	../2-chimera_detection/NU24/NU24-nonchimeras.fasta
# NU3-nc	fasta	../2-chimera_detection/NU3/NU3-nonchimeras.fasta
# NU4-nc	fasta	../2-chimera_detection/NU4/NU4-nonchimeras.fasta
# NU5-nc	fasta	../2-chimera_detection/NU5/NU5-nonchimeras.fasta
# NU6-nc	fasta	../2-chimera_detection/NU6/NU6-nonchimeras.fasta
# NU7-nc	fasta	../2-chimera_detection/NU7/NU7-nonchimeras.fasta
# NU8-nc	fasta	../2-chimera_detection/NU8/NU8-nonchimeras.fasta
# NU9-nc	fasta	../2-chimera_detection/NU9/NU9-nonchimeras.fasta
# P10-1-nc	fasta	../2-chimera_detection/P10-1/P10-1-nonchimeras.fasta
# P10-2-nc	fasta	../2-chimera_detection/P10-2/P10-2-nonchimeras.fasta
# P10-3-nc	fasta	../2-chimera_detection/P10-3/P10-3-nonchimeras.fasta
# P10-4-nc	fasta	../2-chimera_detection/P10-4/P10-4-nonchimeras.fasta
# P10-5-nc	fasta	../2-chimera_detection/P10-5/P10-5-nonchimeras.fasta
# P10-6-nc	fasta	../2-chimera_detection/P10-6/P10-6-nonchimeras.fasta
# P1-1-nc	fasta	../2-chimera_detection/P1-1/P1-1-nonchimeras.fasta
# P11-1-nc	fasta	../2-chimera_detection/P11-1/P11-1-nonchimeras.fasta
# P11-2-nc	fasta	../2-chimera_detection/P11-2/P11-2-nonchimeras.fasta
# P11-3-nc	fasta	../2-chimera_detection/P11-3/P11-3-nonchimeras.fasta
# P11-4-nc	fasta	../2-chimera_detection/P11-4/P11-4-nonchimeras.fasta
# P11-5-nc	fasta	../2-chimera_detection/P11-5/P11-5-nonchimeras.fasta
# P11-6-nc	fasta	../2-chimera_detection/P11-6/P11-6-nonchimeras.fasta
# P1-2-nc	fasta	../2-chimera_detection/P1-2/P1-2-nonchimeras.fasta
# P12-1-nc	fasta	../2-chimera_detection/P12-1/P12-1-nonchimeras.fasta
# P12-2-nc	fasta	../2-chimera_detection/P12-2/P12-2-nonchimeras.fasta
# P12-3-nc	fasta	../2-chimera_detection/P12-3/P12-3-nonchimeras.fasta
# P12-4-nc	fasta	../2-chimera_detection/P12-4/P12-4-nonchimeras.fasta
# P12-5-nc	fasta	../2-chimera_detection/P12-5/P12-5-nonchimeras.fasta
# P12-6-nc	fasta	../2-chimera_detection/P12-6/P12-6-nonchimeras.fasta
# P1-3-nc	fasta	../2-chimera_detection/P1-3/P1-3-nonchimeras.fasta
# P13-1-nc	fasta	../2-chimera_detection/P13-1/P13-1-nonchimeras.fasta
# P13-2-nc	fasta	../2-chimera_detection/P13-2/P13-2-nonchimeras.fasta
# P13-3-nc	fasta	../2-chimera_detection/P13-3/P13-3-nonchimeras.fasta
# P13-4-nc	fasta	../2-chimera_detection/P13-4/P13-4-nonchimeras.fasta
# P13-5-nc	fasta	../2-chimera_detection/P13-5/P13-5-nonchimeras.fasta
# P13-6-nc	fasta	../2-chimera_detection/P13-6/P13-6-nonchimeras.fasta
# P1-4-nc	fasta	../2-chimera_detection/P1-4/P1-4-nonchimeras.fasta
# P14-1-nc	fasta	../2-chimera_detection/P14-1/P14-1-nonchimeras.fasta
# P14-2-nc	fasta	../2-chimera_detection/P14-2/P14-2-nonchimeras.fasta
# P14-3-nc	fasta	../2-chimera_detection/P14-3/P14-3-nonchimeras.fasta
# P14-4-nc	fasta	../2-chimera_detection/P14-4/P14-4-nonchimeras.fasta
# P14-5-nc	fasta	../2-chimera_detection/P14-5/P14-5-nonchimeras.fasta
# P14-6-nc	fasta	../2-chimera_detection/P14-6/P14-6-nonchimeras.fasta
# P1-5-nc	fasta	../2-chimera_detection/P1-5/P1-5-nonchimeras.fasta
# P15-1-nc	fasta	../2-chimera_detection/P15-1/P15-1-nonchimeras.fasta
# P15-2-nc	fasta	../2-chimera_detection/P15-2/P15-2-nonchimeras.fasta
# P15-3-nc	fasta	../2-chimera_detection/P15-3/P15-3-nonchimeras.fasta
# P15-4-nc	fasta	../2-chimera_detection/P15-4/P15-4-nonchimeras.fasta
# P15-5-nc	fasta	../2-chimera_detection/P15-5/P15-5-nonchimeras.fasta
# P15-6-nc	fasta	../2-chimera_detection/P15-6/P15-6-nonchimeras.fasta
# P1-6-nc	fasta	../2-chimera_detection/P1-6/P1-6-nonchimeras.fasta
# P16-1-nc	fasta	../2-chimera_detection/P16-1/P16-1-nonchimeras.fasta
# P16-2-nc	fasta	../2-chimera_detection/P16-2/P16-2-nonchimeras.fasta
# P16-3-nc	fasta	../2-chimera_detection/P16-3/P16-3-nonchimeras.fasta
# P16-4-nc	fasta	../2-chimera_detection/P16-4/P16-4-nonchimeras.fasta
# P16-5-nc	fasta	../2-chimera_detection/P16-5/P16-5-nonchimeras.fasta
# P16-6-nc	fasta	../2-chimera_detection/P16-6/P16-6-nonchimeras.fasta
# P17-1-nc	fasta	../2-chimera_detection/P17-1/P17-1-nonchimeras.fasta
# P17-2-nc	fasta	../2-chimera_detection/P17-2/P17-2-nonchimeras.fasta
# P17-3-nc	fasta	../2-chimera_detection/P17-3/P17-3-nonchimeras.fasta
# P17-4-nc	fasta	../2-chimera_detection/P17-4/P17-4-nonchimeras.fasta
# P17-5-nc	fasta	../2-chimera_detection/P17-5/P17-5-nonchimeras.fasta
# P17-6-nc	fasta	../2-chimera_detection/P17-6/P17-6-nonchimeras.fasta
# P18-1-nc	fasta	../2-chimera_detection/P18-1/P18-1-nonchimeras.fasta
# P18-2-nc	fasta	../2-chimera_detection/P18-2/P18-2-nonchimeras.fasta
# P18-3-nc	fasta	../2-chimera_detection/P18-3/P18-3-nonchimeras.fasta
# P18-4-nc	fasta	../2-chimera_detection/P18-4/P18-4-nonchimeras.fasta
# P18-5-nc	fasta	../2-chimera_detection/P18-5/P18-5-nonchimeras.fasta
# P18-6-nc	fasta	../2-chimera_detection/P18-6/P18-6-nonchimeras.fasta
# P19-1-nc	fasta	../2-chimera_detection/P19-1/P19-1-nonchimeras.fasta
# P19-2-nc	fasta	../2-chimera_detection/P19-2/P19-2-nonchimeras.fasta
# P19-3-nc	fasta	../2-chimera_detection/P19-3/P19-3-nonchimeras.fasta
# P19-4-nc	fasta	../2-chimera_detection/P19-4/P19-4-nonchimeras.fasta
# P19-5-nc	fasta	../2-chimera_detection/P19-5/P19-5-nonchimeras.fasta
# P19-6-nc	fasta	../2-chimera_detection/P19-6/P19-6-nonchimeras.fasta
# P2-1-nc	fasta	../2-chimera_detection/P2-1/P2-1-nonchimeras.fasta
# P2-2-nc	fasta	../2-chimera_detection/P2-2/P2-2-nonchimeras.fasta
# P2-3-nc	fasta	../2-chimera_detection/P2-3/P2-3-nonchimeras.fasta
# P2-4-nc	fasta	../2-chimera_detection/P2-4/P2-4-nonchimeras.fasta
# P2-5-nc	fasta	../2-chimera_detection/P2-5/P2-5-nonchimeras.fasta
# P2-6-nc	fasta	../2-chimera_detection/P2-6/P2-6-nonchimeras.fasta
# P3-1-nc	fasta	../2-chimera_detection/P3-1/P3-1-nonchimeras.fasta
# P3-2-nc	fasta	../2-chimera_detection/P3-2/P3-2-nonchimeras.fasta
# P3-3-nc	fasta	../2-chimera_detection/P3-3/P3-3-nonchimeras.fasta
# P3-4-nc	fasta	../2-chimera_detection/P3-4/P3-4-nonchimeras.fasta
# P3-5-nc	fasta	../2-chimera_detection/P3-5/P3-5-nonchimeras.fasta
# P3-6-nc	fasta	../2-chimera_detection/P3-6/P3-6-nonchimeras.fasta
# P4-1-nc	fasta	../2-chimera_detection/P4-1/P4-1-nonchimeras.fasta
# P4-2-nc	fasta	../2-chimera_detection/P4-2/P4-2-nonchimeras.fasta
# P4-3-nc	fasta	../2-chimera_detection/P4-3/P4-3-nonchimeras.fasta
# P4-4-nc	fasta	../2-chimera_detection/P4-4/P4-4-nonchimeras.fasta
# P4-5-nc	fasta	../2-chimera_detection/P4-5/P4-5-nonchimeras.fasta
# P4-6-nc	fasta	../2-chimera_detection/P4-6/P4-6-nonchimeras.fasta
# P5-1-nc	fasta	../2-chimera_detection/P5-1/P5-1-nonchimeras.fasta
# P5-2-nc	fasta	../2-chimera_detection/P5-2/P5-2-nonchimeras.fasta
# P5-3-nc	fasta	../2-chimera_detection/P5-3/P5-3-nonchimeras.fasta
# P5-4-nc	fasta	../2-chimera_detection/P5-4/P5-4-nonchimeras.fasta
# P5-5-nc	fasta	../2-chimera_detection/P5-5/P5-5-nonchimeras.fasta
# P5-6-nc	fasta	../2-chimera_detection/P5-6/P5-6-nonchimeras.fasta
# P6-1-nc	fasta	../2-chimera_detection/P6-1/P6-1-nonchimeras.fasta
# P6-2-nc	fasta	../2-chimera_detection/P6-2/P6-2-nonchimeras.fasta
# P6-3-nc	fasta	../2-chimera_detection/P6-3/P6-3-nonchimeras.fasta
# P6-4-nc	fasta	../2-chimera_detection/P6-4/P6-4-nonchimeras.fasta
# P6-5-nc	fasta	../2-chimera_detection/P6-5/P6-5-nonchimeras.fasta
# P6-6-nc	fasta	../2-chimera_detection/P6-6/P6-6-nonchimeras.fasta
# P7-1-nc	fasta	../2-chimera_detection/P7-1/P7-1-nonchimeras.fasta
# P7-2-nc	fasta	../2-chimera_detection/P7-2/P7-2-nonchimeras.fasta
# P7-3-nc	fasta	../2-chimera_detection/P7-3/P7-3-nonchimeras.fasta
# P7-4-nc	fasta	../2-chimera_detection/P7-4/P7-4-nonchimeras.fasta
# P7-5-nc	fasta	../2-chimera_detection/P7-5/P7-5-nonchimeras.fasta
# P7-6-nc	fasta	../2-chimera_detection/P7-6/P7-6-nonchimeras.fasta
# P8-1-nc	fasta	../2-chimera_detection/P8-1/P8-1-nonchimeras.fasta
# P8-2-nc	fasta	../2-chimera_detection/P8-2/P8-2-nonchimeras.fasta
# P8-3-nc	fasta	../2-chimera_detection/P8-3/P8-3-nonchimeras.fasta
# P8-4-nc	fasta	../2-chimera_detection/P8-4/P8-4-nonchimeras.fasta
# P8-5-nc	fasta	../2-chimera_detection/P8-5/P8-5-nonchimeras.fasta
# P8-6-nc	fasta	../2-chimera_detection/P8-6/P8-6-nonchimeras.fasta
# P9-1-nc	fasta	../2-chimera_detection/P9-1/P9-1-nonchimeras.fasta
# P9-2-nc	fasta	../2-chimera_detection/P9-2/P9-2-nonchimeras.fasta
# P9-3-nc	fasta	../2-chimera_detection/P9-3/P9-3-nonchimeras.fasta
# P9-4-nc	fasta	../2-chimera_detection/P9-4/P9-4-nonchimeras.fasta
# P9-5-nc	fasta	../2-chimera_detection/P9-5/P9-5-nonchimeras.fasta
# P9-6-nc	fasta	../2-chimera_detection/P9-6/P9-6-nonchimeras.fasta

# %% [markdown]
# That's almost it. Now start the pipeline to do sequence clustering and taxonomic assignment of non-chimera queries via metaBEAT. As input, Querymap.txt containing samples that have been trimmed, merged and checked for chimeras, and the REFmap.txt file must be specified. metaBEAT will be asked to attempt taxonomic assignment with the two different approaches mentioned above.
#
# Kraken requires a specific database that metaBEAT will build automatically if necessary.
#
# metaBEAT will automatically wrangle the data into the particular file formats that are required by each of the methods, run all necessary steps, and finally convert the outputs of each program to a standardized BIOM table.
#
# **GO!**

# %%
# !metaBEAT_global.py -h
# Out:
# usage: metaBEAT.py [-h] [-Q <FILE>] [-B <FILE>] [--g_queries <FILE>] [-v] [-s]
#                    [-f] [-p] [-k] [-t] [-b] [-m <string>] [-n <INT>] [-E] [-e]
#                    [--read_stats_off] [--PCR_primer <FILE>] [--bc_dist <INT>]
#                    [--trim_adapter <FILE>] [--trim_qual <INT>] [--phred <INT>]
#                    [--trim_window <INT>] [--read_crop <INT>]
#                    [--trim_minlength <INT>] [--merge] [--product_length <INT>]
#                    [--merged_only] [--forward_only] [--length_filter <INT>]
#                    [--length_deviation <FLOAT>] [-R <FILE>] [--gb_out <FILE>]
#                    [--rec_check] [--gb_to_taxid <FILE>] [--cluster]
#                    [--clust_match <FLOAT>] [--clust_cov <INT>]
#                    [--blast_db <PATH>] [--blast_xml <PATH>]
#                    [--update_taxonomy] [--taxonomy_db <FILE>]
#                    [--min_ident <FLOAT>] [--min_ali_length <FLOAT>]
#                    [--bitscore_skim_LCA <FLOAT>] [--bitscore_skim_adjust_off]
#                    [--min_bit <INT>] [--refpkg <DIR>] [--jplace <FILE>]
#                    [--jellyfish_hash_size <STR>] [--kraken_db <DIR>]
#                    [--kraken_score_threshold <FLOAT>] [--rm_kraken_db]
#                    [-o OUTPUT_PREFIX] [--metadata METADATA]
#                    [-@ <email-address>] [--version]
#
# metaBEAT - metaBarcoding and Environmental DNA Analyses tool version:
# v.0.97.11-global
#
# optional arguments:
#   -h, --help            show this help message and exit
#   -Q <FILE>, --querylist <FILE>
#                         file containing a list of query files
#   -B <FILE>, --BIOM_input <FILE>
#                         OTU table in BIOM format
#   --g_queries <FILE>    fasta file containing query sequences (in combination
#                         with '-B' sequence headers are expected to match)
#   -v, --verbose         turn verbose output on
#   -s, --seqinfo         write out seq_info.csv file
#   -f, --fasta           write out ref.fasta file
#   -p, --pplace          perform phylogenetic placement
#   -k, --kraken          perform phylogenetic placement
#   -t, --taxids          write out taxid.txt file
#   -b, --blast           compile local blast db and blast queries
#   -m <string>, --marker <string>
#                         marker ID (default: marker)
#   -n <INT>, --n_threads <INT>
#                         Number of threads (default: 1)
#   -E, --extract_centroid_reads
#                         extract centroid reads to files
#   -e, --extract_all_reads
#                         extract reads to files
#   --read_stats_off      ommit writing read stats to file
#   --version             show program's version number and exit
#
# Query preprocessing:
#   The parameters in this group affect how the query sequences are processed
#
#   --PCR_primer <FILE>   PCR primers (provided in fasta file) to be clipped
#                         from reads
#   --bc_dist <INT>       Number of mismatches allowed in barcode sequences
#   --trim_adapter <FILE>
#                         trim adapters provided in file
#   --trim_qual <INT>     minimum phred quality score (default: 30)
#   --phred <INT>         phred quality score offset - 33 or 64 (default: 33)
#   --trim_window <INT>   sliding window size (default: 5) for trimming; if
#                         average quality drops below the specified minimum
#                         quality all subsequent bases are removed from the
#                         reads
#   --read_crop <INT>     Crop reads to this length if they are longer than that
#                         (default: off)
#   --trim_minlength <INT>
#                         minimum length of reads to be retained after trimming
#                         (default: 50)
#   --merge               attempt to merge paired-end reads
#   --product_length <INT>
#                         estimated length of PCR product (specifying this
#                         option increases merging efficiency)
#   --merged_only         only process successfully merged read-pairs
#   --forward_only        only process sequences that contain forward reads
#                         (i.e. unmerged forward reads and merged reads)
#   --length_filter <INT>
#                         only process reads, which are within +/- 10 percent of
#                         this length
#   --length_deviation <FLOAT>
#                         allowed deviation (in percent) from length specified
#                         by --length_filter (default=0.1)
#
# Reference:
#   The parameters in this group affect the reference to be used in the
#   analyses
#
#   -R <FILE>, --REFlist <FILE>
#                         file containing a list of files to be used as
#                         reference sequences
#   --gb_out <FILE>       output the corrected gb file
#   --rec_check           check records to be used as reference
#   --gb_to_taxid <FILE>  comma delimited file containing 'gb accession,taxid'
#                         for a list of taxa
#
# Query clustering options:
#   The parameters in this group affect read clustering
#
#   --cluster             perform clustering of query sequences using vsearch
#   --clust_match <FLOAT>
#                         identity threshold for clustering in percent (default:
#                         1)
#   --clust_cov <INT>     minimum number of records in cluster (default: 1)
#
# BLAST search:
#   The parameters in this group affect BLAST search and BLAST based taxonomic
#   assignment
#
#   --blast_db <PATH>     path to precompiled blast database
#   --blast_xml <PATH>    path to Blast result in xml format
#   --update_taxonomy     Download/update taxonomy database. Database will be
#                         called 'taxonomy.db' and will be compiled in the same
#                         location as the metaBEAT.py script.
#   --taxonomy_db <FILE>  taxonomy database file location. In case it's not the
#                         default, which is 'taxonomy.db' in the same directory
#                         as the metaBEAT.py script.
#   --min_ident <FLOAT>   minimum identity threshold in percent (default: 0.80)
#   --min_ali_length <FLOAT>
#                         minimum alignment length in percent of total query
#                         length (default: 0.95)
#   --bitscore_skim_LCA <FLOAT>
#                         Only BLAST hits with bitscores differing by less than
#                         this factor from the top hit (bitscore skim window)
#                         will be considered for LCA (0-1; default: 0.1)
#   --bitscore_skim_adjust_off
#                         Per default a 100% identity BLAST top hit across the
#                         minimum alignment length triggers an adjustment of the
#                         bitscore skim window to '0', i.e. only hits with
#                         bitscores as good as the top hit are considered for
#                         LCA. This flag switches this behaviour off.
#   --min_bit <INT>       minimum bitscore (default: 80)
#
# Phylogenetic placement:
#   The parameters in this group affect phylogenetic placement
#
#   --refpkg <DIR>        PATH to refpkg for pplacer
#   --jplace <FILE>       phylogenetic placement result from prefious pplacer
#                         run in *.jplace format
#
# Kraken:
#   The parameters in this group affect taxonomic assignment using Kraken
#
#   --jellyfish_hash_size <STR>
#                         jellyfish hash size to control memory usage during
#                         kraken database building. A table size of '6400M' will
#                         require ~44G of RAM. '2700M' -> 20G RAM.
#   --kraken_db <DIR>     PATH to a Kraken database
#   --kraken_score_threshold <FLOAT>
#                         minimum proportion of k-mers to support assignment
#                         (0-1; default: 0)
#   --rm_kraken_db        Remove Kraken database after successful completion
#
# BIOM OUTPUT:
#   The arguments in this groups affect the output in BIOM format
#
#   -o OUTPUT_PREFIX, --output_prefix OUTPUT_PREFIX
#                         prefix for BIOM output files (default='metaBEAT')
#   --metadata METADATA   comma delimited file containing metadata (optional)
#
# Entrez identification:
#   metaBEAT is querying the NCBI Entrez databases, please provide an email
#   address for identification
#
#   -@ <email-address>, --email <email-address>
#                         provide your email address for identification to NCBI

# %%
# %%bash
#
# metaBEAT_global.py \
# -Q Querymap_final.txt \
# -R REFmap.txt \
# --cluster --clust_match 0.97 --clust_cov 5 \
# --blast --min_ident 0.95 --min_ali_length 0.8 \
# -m 12S -n 5 \
# -E -v \
# -@ L.Harper@2015.hull.ac.uk \
# -o 12S-trim30_crop110_min90_merge-forwonly_nonchimera_c0.97cov5_blast95-id1 &> log95

# %%
# !tail -n 50 log95

# %% [markdown]
# metaBEAT will generate a directory with all temporary files that were created during the processing for each sample and will record useful stats summarizing the data processing in the file `12S-trim30_crop110_min90_merge-forwonly_nonchimera_c0.97cov5_blast95-id1_read_stats.csv`.
#
# Note that the entire process only took ~10 minutes.
#
# All BLAST outputs are kept in the directory `./GLOBAL`.
#
# metaBEAT has produced results tables in BIOM format for each of the approaches in the corresponding directory.
# A nice tool for interactive exploration of results is phinch. Load one of the tables (`*.biom`) and see if you can get an overview of the results.

# %% [markdown]
# **OR**
#
# If you experience an error, the chances are this is related to changes in the NCBI taxonomy database. The metaBEAT image comes prepared with a database that contains taxonomic information for taxids. However, new taxids are constantly being added to GenBank, and the database contained in the image (`/usr/bin/taxonomy.db`) is not necessarily up to date. If the above command gives you errors about certain taxids not being found in the database. or KeyErrors relating to a taxid, you will need to do one or all of the following:
# 1. Create a `gb_to_taxid.csv` file with the problematic taxid and corresponding gi number
# 2. Update the local taxonomy database that metaBEAT uses.
# 3. Manually add taxids to the local taxonomy database.
# 4. Manually search for the gi number/taxid that causes the pipeline to break, and add it along with the corresponding gi number/taxid to the `gi_to_taxid.csv` file.

# %% [markdown]
# We have provided the `gb_to_taxid.csv` file created when we performed an unassigned BLAST against the entire NCBI nucleotide database during our analysis. It is in `../Jupyter_notebooks` but must be moved to the same directory where the current notebook is performing the BLAST. In this case, `./3-taxonomic_assignment`.

# %%
# !mv ../Jupyter_notebooks/gb_to_taxid.csv ../3-taxonomic_assignment/

# %% [markdown]
# Now rerun the metaBEAT command to see if taxonomy issues have been resolved.

# %% [markdown]
# To update the local taxonomy database:

# %%
# %%bash
#
# # Remove the old database
# rm /usr/bin/taxonomy.db
#
# # Create a new database. This command will first download the latest NCBI taxonomy info (taxdmp.zip) and configure the database
# taxit new_database -d /usr/bin/taxonomy.db
#
# # Remove temporal file that has been downloaded by the previous command
# rm /usr/bin/taxdmp.zip
# Out:
# usage: taxit [-h] [-V] [-v] [-q]
#              {help,add_nodes,add_to_taxtable,check,composition,create,extract_nodes,findcompany,get_lineage,info,lineage_table,lonelynodes,namelookup,new_database,refpkg_intersection,reroot,rollback,rollforward,rp,strip,taxids,taxtable,update,update_taxids}
#              ...
# taxit: error: unrecognized arguments: -d
# rm: cannot remove ‘/usr/bin/taxdmp.zip’: No such file or directory

# %%
# %%bash
#
# # Remove the old database
# rm /usr/bin/taxonomy.db
#
# # Create a new database. This command will first download the latest NCBI taxonomy info (taxdmp.zip) and configure the database
# taxit new_database -u ftp://ftp.ncbi.nih.gov/pub/taxonomy/taxdmp.zip -p /usr/bin/
#
# # Remove temporal file that has been downloaded by the previous command
# rm /usr/bin/taxdmp.zip
# Out:
# rm: cannot remove ‘/usr/bin/taxonomy.db’: No such file or directory

# %%
# %%bash
#
# # Remove the old database
# rm -r /usr/bin/taxonomy.db
#
# # Make directory for new database
# mkdir /usr/bin/taxonomy.db
#
# # This command will download the latest NCBI taxonomy info (taxdmp.zip) into the created directory
# taxit new_database -u ftp://ftp.ncbi.nih.gov/pub/taxonomy/taxdmp.zip -p /usr/bin/taxonomy.db/
#
# # Unzip taxdmp.zip file to configure the database. Need to specify the destination directory.
# unzip /usr/bin/taxonomy.db/taxdmp.zip -d /usr/bin/taxonomy.db/
#
# # Remove temporal file that was been downloaded by the previous command
# rm /usr/bin/taxonomy.db/taxdmp.zip
# Out:
# Archive:  /usr/bin/taxonomy.db/taxdmp.zip
#   inflating: /usr/bin/taxonomy.db/citations.dmp
#   inflating: /usr/bin/taxonomy.db/delnodes.dmp
#   inflating: /usr/bin/taxonomy.db/division.dmp
#   inflating: /usr/bin/taxonomy.db/gencode.dmp
#   inflating: /usr/bin/taxonomy.db/merged.dmp
#   inflating: /usr/bin/taxonomy.db/names.dmp
#   inflating: /usr/bin/taxonomy.db/nodes.dmp
#   inflating: /usr/bin/taxonomy.db/gc.prt
#   inflating: /usr/bin/taxonomy.db/readme.txt

# %%
# %%bash
#
# # Remove the old database
# rm -r /usr/bin/taxonomy.db
#
# # This command will download the latest NCBI taxonomy info (taxdmp.zip) into the created directory
# taxit new_database -u ftp://ftp.ncbi.nih.gov/pub/taxonomy/taxdmp.zip -p /usr/bin/
#
# # Unzip taxdmp.zip file to configure the database. Need to specify the destination directory.
# unzip /usr/bin/taxdmp.zip -d /usr/bin/taxonomy.db/
#
# # Remove temporal file that was been downloaded by the previous command
# rm /usr/bin/taxdmp.zip
# Out:
# Archive:  /usr/bin/taxdmp.zip
#   inflating: /usr/bin/taxonomy.db/citations.dmp
#   inflating: /usr/bin/taxonomy.db/delnodes.dmp
#   inflating: /usr/bin/taxonomy.db/division.dmp
#   inflating: /usr/bin/taxonomy.db/gencode.dmp
#   inflating: /usr/bin/taxonomy.db/merged.dmp
#   inflating: /usr/bin/taxonomy.db/names.dmp
#   inflating: /usr/bin/taxonomy.db/nodes.dmp
#   inflating: /usr/bin/taxonomy.db/gc.prt
#   inflating: /usr/bin/taxonomy.db/readme.txt
# rm: cannot remove ‘/usr/bin/taxonomy.db’: No such file or directory

# %%
# !ls /usr/bin/taxonomy.db
# Out:
# citations.dmp  division.dmp  gencode.dmp  names.dmp  readme.txt
# delnodes.dmp   gc.prt	     merged.dmp   nodes.dmp

# %% [markdown]
# This will take a few minutes, depending on your internet connection. Once updated, try rerunning the metaBEAT command.
#
# An error still comes up if one or more taxids that are present in the taxid files (`gi_to_taxid.csv`, `gb_to_taxid.csv`, `taxid.txt`), but are not present in the taxonomy database that the current metaBEAT image contains. Reasons for this are not clear. However, if the updated taxonomy database fails again, a possible way around is to manually add the problematic taxid to the taxonomy database. This involves created a new node in the taxonomy database. You will have to create a csv file for each node to be added formatted like so:
#
# "tax_id","parent_id","rank","tax_name"
#
# "1825799","190765","species","Ochlerotatus cantans"
#
# There must only be one row per node but you may add as many new nodes as the number of taxids that metaBEAT could not find in the taxonomy database.
#
# To add the nodes to the taxonomy database, use this command:

# %%
#!taxit add_nodes -d /usr/bin/taxonomy.db -N ../new_taxids.csv

# %%
# !taxit -h
# Out:
# usage: taxit [-h] [-V] [-v] [-q]
#              {help,add_nodes,add_to_taxtable,check,composition,create,extract_nodes,findcompany,get_lineage,info,lineage_table,lonelynodes,namelookup,new_database,refpkg_intersection,reroot,rollback,rollforward,rp,strip,taxids,taxtable,update,update_taxids}
#              ...
#
# Creation, validation, and modification of reference packages for use with
# `pplacer` and related software.
#
# positional arguments:
#   {help,add_nodes,add_to_taxtable,check,composition,create,extract_nodes,findcompany,get_lineage,info,lineage_table,lonelynodes,namelookup,new_database,refpkg_intersection,reroot,rollback,rollforward,rp,strip,taxids,taxtable,update,update_taxids}
#     help                Detailed help for actions using `help <action>`
#     add_nodes           Add nodes and names to a database
#     add_to_taxtable     Add nodes to an existing taxtable csv
#     check               Validate a reference package
#     composition         Show taxonomic composition of a reference package
#     create              Create a reference package
#     extract_nodes       Extract nodes from a given source in yaml format
#     findcompany         Find company for lonely nodes
#     get_lineage         Calculate the taxonomic lineage of a taxid
#     info                Show information about reference packages.
#     lineage_table       Create a table of lineages as taxonimic names for a
#                         collection of sequences
#     lonelynodes         Extracts tax ids of all lonely nodes in a taxtable
#     namelookup          Find primary name and tax_id from taxonomic names
#     new_database        Download NCBI taxonomy and create a database
#     refpkg_intersection
#                         Find the intersection of a taxtable and a refpkg's
#                         taxonomy.
#     reroot              Taxonomically reroots a reference package
#     rollback            Undo an operation performed on a refpkg
#     rollforward         Restore a change to a refpkg immediately after being
#                         reverted
#     rp                  Resolve path; get the path to a file in the reference
#                         package
#     strip               Remove rollback and rollforward information from a
#                         refpkg
#     taxids              Convert a list of taxonomic names into a recursive
#                         list of species
#     taxtable            Create a tabular representation of taxonomic lineages
#     update              Add or modify files or metadata in a refpkg
#     update_taxids       Update obsolete tax_ids
#
# optional arguments:
#   -h, --help            show this help message and exit
#   -V, --version         Print the version number and exit
#   -v, --verbose         Increase verbosity of screen output (eg, -v is
#                         verbose, -vv more so)
#   -q, --quiet           Suppress output

# %% [markdown]
# If repeating analysis once databases have been created:

# %%
# metaBEAT_global.py \
#-Q Querymap_final.txt \
#-R REFmap.txt \
#--cluster --clust_match 0.97 --clust_cov 5 \
#--blast --blast_xml ./GLOBAL/BLAST_0.95/global_blastn.out.xml --min_ident 0.95 --min_ali_length 0.8 \
#-m 12S -n 5 \
#-E -v \
#-@ L.Harper@2015.hull.ac.uk \
#-o 12S-trim30_crop110_min90_merge-forwonly_nonchimera_c0.97cov5_blast95-id1 &> log95

# %% [markdown]
# Repeat the metaBEAT analysis at increasing minimum identity thresholds for the BLAST search.

# %%
# %%bash
#
# metaBEAT_global.py \
# -Q Querymap_final.txt \
# -R REFmap.txt \
# --cluster --clust_match 0.97 --clust_cov 5 \
# --blast --min_ident 0.96 --min_ali_length 0.8 \
# -m 12S -n 5 \
# -E -v \
# -@ L.Harper@2015.hull.ac.uk \
# -o 12S-trim30_crop110_min90_merge-forwonly_nonchimera_c0.97cov5_blast96-id1 &> log0.96

# %%
# %%bash
#
# metaBEAT_global.py \
# -Q Querymap_final.txt \
# -R REFmap.txt \
# --cluster --clust_match 0.97 --clust_cov 5 \
# --blast --min_ident 0.97 --min_ali_length 0.8 \
# -m 12S -n 5 \
# -E -v \
# -@ L.Harper@2015.hull.ac.uk \
# -o 12S-trim30_crop110_min90_merge-forwonly_nonchimera_c0.97cov5_blast97-id1 &> log97

# %%
# %%bash
#
# metaBEAT_global.py \
# -Q Querymap_final.txt \
# -R REFmap.txt \
# --cluster --clust_match 0.97 --clust_cov 5 \
# --blast --min_ident 0.98 --min_ali_length 0.8 \
# -m 12S -n 5 \
# -E -v \
# -@ L.Harper@2015.hull.ac.uk \
# -o 12S-trim30_crop110_min90_merge-forwonly_nonchimera_c0.97cov5_blast98-id1 &> log98

# %%
# %%bash
#
# metaBEAT_global.py \
# -Q Querymap_final.txt \
# -R REFmap.txt \
# --cluster --clust_match 0.97 --clust_cov 5 \
# --blast --min_ident 0.99 --min_ali_length 0.8 \
# -m 12S -n 5 \
# -E -v \
# -@ L.Harper@2015.hull.ac.uk \
# -o 12S-trim30_crop110_min90_merge-forwonly_nonchimera_c0.97cov5_blast99-id1 &> log99

# %%
# %%bash
#
# metaBEAT_global.py \
# -Q Querymap_final.txt \
# -R REFmap.txt \
# --cluster --clust_match 0.97 --clust_cov 5 \
# --blast --min_ident 1 --min_ali_length 0.8 \
# -m 12S -n 5 \
# -E -v \
# -@ L.Harper@2015.hull.ac.uk \
# -o 12S-trim30_crop110_min90_merge-forwonly_nonchimera_c0.97cov5_blast100-id1 &> log100

# %% [markdown]
# After inspection of the taxonomic assignment at different BLAST minimum identity thresholds, it was decided to progress with a minimum identity threshold of 98% as this included sound identification of species. Lower thresholds included spurious species such as *Lota lota*, an introduced fish species not present in ponds, and higher thresholds removed common and native pond species with high read counts such as *Lissotrition vulgaris*. Due to high variability of the 12S rRNA region, a 1 or 2 bp mismatch can prevent assignment of some species at high BLAST identity thresholds.
#
# Re-run the BLAST at minimum identity threshold of 98% so that `./GLOBAL` files, including `global_queries.fasta`, contain these results rather than last BLAST search at 100%. These files will be required to perform a BLAST of the unassigned reads.

# %%
# %%bash
#
# metaBEAT_global.py \
# -Q Querymap_final.txt \
# -R REFmap.txt \
# --cluster --clust_match 0.97 --clust_cov 5 \
# --blast --min_ident 0.98 --min_ali_length 0.8 \
# -m 12S -n 5 \
# -E -v \
# -@ L.Harper@2015.hull.ac.uk \
# -o 12S-trim30_crop110_min90_merge-forwonly_nonchimera_c0.97cov5_blast98-id1 &> log98
